# %%
import os, re, time, json
import pandas as pd
import requests
from requests.adapters import HTTPAdapter, Retry
from concurrent.futures import ThreadPoolExecutor, as_completed
from typing import List, Dict, Any, Optional


headers = {
    "accept": "application/json, text/javascript, */*; q=0.01",
    "accept-encoding": "gzip, deflate, br, zstd",
    "accept-language": "ko,ko-KR;q=0.9,en-US;q=0.8,en;q=0.7",
    "origin": "https://www.encar.com",
    "referer": "https://www.encar.com/",
    "sec-ch-ua": '"Chromium";v="140", "Not=A?Brand";v="24", "Google Chrome";v="140"',
    "sec-ch-ua-mobile": "?0",
    "sec-ch-ua-platform": '"Windows"',
    "sec-fetch-dest": "empty",
    "sec-fetch-mode": "cors",
    "sec-fetch-site": "same-site",
    "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/140.0.0.0 Safari/537.36"
}
#전체 차량 카운트 api
res = requests.get('https://api.encar.com/search/car/list/general?count=true&q=(And.Hidden.N._.CarType.N.)&inav=%7CMetadata%7CSort', headers=headers)


res.status_code
# Out:
# 200

# %%
page = 0            # 0,1,2,...
page_size = 50
start = page * page_size
url = "https://api.encar.com/search/car/list/general"

params = {
    # 일반광고 필터(AdType.A) 제거 → 전체 매물
    "q": "(And.Hidden.N._.(C.CarType.Y._.(C.Manufacturer.현대._.ModelGroup.그랜저.)))",
    "sr": f"|ModifiedDate|{start}|{page_size}",
}


# 현대 그랜저 차량 목록(전체 매물)
res = requests.get(url, headers=headers,params=params)

res.status_code
# Out:
# 200

# %%
res.json()
# Out:
# {'SearchResults': [{'Id': '37210236',
#    'Separation': ['B'],
#    'Trust': ['ExtendWarranty', 'HomeService'],
#    'ServiceMark': ['EncarMeetgo', 'EncarDiagnosisP1'],
#    'Condition': ['Inspection', 'Record', 'Resume'],
#    'Photo': '/carpicture01/pic3721/37210233_',
#    'Photos': [{'type': '001',
#      'location': '/carpicture01/pic3721/37210233_001.jpg',
#      'updatedDate': '2024-04-19T06:20:57Z',
#      'ordering': 1.0},
#     {'type': '003',
#      'location': '/carpicture01/pic3721/37210233_003.jpg',
#      'updatedDate': '2024-04-19T06:20:57Z',
#      'ordering': 3.0},
#     {'type': '004',
#      'location': '/carpicture01/pic3721/37210233_004.jpg',
#      'updatedDate': '2024-04-19T06:20:57Z',
#      'ordering': 4.0},
#     {'type': '007',
#      'location': '/carpicture01/pic3721/37210233_007.jpg',
#      'updatedDate': '2024-04-19T06:20:57Z',
#      'ordering': 7.0}],
#    'Manufacturer': '현대',
#    'Model': '그랜저 하이브리드 (GN7)',
#    'Badge': '캘리그래피',
#    'GreenType': 'Y',
#    'EvType': '하이브리드',
#    'FuelType': '가솔린+전기',
#    'Year': 202301.0,
#    'FormYear': '2023',
#    'Mileage': 15199.0,
#    'HomeServiceVerification': 'Y',
#    'ServiceCopyCar': 'DUPLICATION',
#    'Price': 4099.0,
#    'SellType': '일반',
#    'BuyType': ['Delivery'],
#    'OfficeCityState': '경기'},
#   {'Id': '40326693',
#    'Separation': ['B'],
#    'Trust': ['ExtendWarranty', 'Meetgo'],
#    'ServiceMark': ['EncarMeetgo', 'EncarDiagnosisP2'],
#    'Condition': ['Inspection', 'InspectionDirect', 'Record', 'Resume'],
#    'Photo': '/carpicture02/pic4032/40326679_',
#    'Photos': [{'type': '001',
#      'location': '/carpicture02/pic4032/40326679_027.jpg',
#      'updatedDate': '2025-08-19T06:15:04Z',
#      'ordering': 1.0},
#     {'type': '003',
#      'location': '/carpicture02/pic4032/40326679_003.jpg',
#      'updatedDate': '2025-08-19T06:15:04Z',
#      'ordering': 3.0},
#     {'type': '004',
#      'location': '/carpicture02/pic4032/40326679_004.jpg',
#      'updatedDate': '2025-08-19T06:15:04Z',
#      'ordering': 4.0},
#     {'type': '007',
#      'location': '/carpicture02/pic4032/40326679_007.jpg',
#      'updatedDate': '2025-08-19T06:15:04Z',
#      'ordering': 7.0}],
#    'Manufacturer': '현대',
#    'Model': '그랜저 IG',
#    'Badge': '2.4 프리미엄',
#    'BadgeDetail': '(세부등급 없음)',
#    'GreenType': 'N',
#    'FuelType': '가솔린',
#    'Year': 201711.0,
#    'FormYear': '2018',
#    'Mileage': 23786.0,
#    'ServiceCopyCar': 'DUPLICATION',
#    'Price': 1990.0,
#    'SellType': '일반',
#    'BuyType': ['Visit'],
#    'OfficeCityState': '서울'},
#   {'Id': '40432990',
#    'Separation': ['B'],
#    'Trust': ['ExtendWarranty', 'HomeService'],
#    'ServiceMark': ['EncarMeetgo', 'EncarDiagnosisP1'],
#    'Condition': ['Inspection', 'Record', 'Resume'],
#    'Photo': '/carpicture02/pic4042/40428533_',
#    'Photos': [{'type': '001',
#      'location': '/carpicture02/pic4042/40428533_001.jpg',
#      'updatedDate': '2025-09-02T03:32:03Z',
#      'ordering': 1.0},
#     {'type': '003',
#      'location': '/carpicture02/pic4042/40428533_003.jpg',
#      'updatedDate': '2025-09-02T03:32:03Z',
#      'ordering': 3.0},
#     {'type': '004',
#      'location': '/carpicture02/pic4042/40428533_004.jpg',
#      'updatedDate': '2025-09-02T03:32:03Z',
#      'ordering': 4.0},
#     {'type': '007',
#      'location': '/carpicture02/pic4042/40428533_007.jpg',
#      'updatedDate': '2025-09-02T03:32:03Z',
#      'ordering': 7.0}],
#    'Manufacturer': '현대',
#    'Model': '더 뉴 그랜저 IG',
#    'Badge': '2.5',
#    'BadgeDetail': '프리미엄',
#    'GreenType': 'N',
#    'FuelType': '가솔린',
#    'Year': 202207.0,
#    'FormYear': '2023',
#    'Mileage': 41188.0,
#    'HomeServiceVerification': 'Y',
#    'ServiceCopyCar': 'DUPLICATION',
#    'Price': 2530.0,
#    'SellType': '일반',
#    'BuyType': ['Delivery'],
#    'OfficeCityState': '서울'},
#   {'Id': '40560529',
#    'Separation': ['B'],
#    'Trust': ['ExtendWarranty', 'HomeService'],
#    'ServiceMark': ['EncarMeetgo', 'EncarDiagnosisP1'],
#    'Condition': ['Inspection', 'Record', 'Resume'],
#    'Photo': '/carpicture01/pic4011/40110627_',
#    'Photos': [{'type': '001',
#      'location': '/carpicture01/pic4011/40110627_001.jpg',
#      'updatedDate': '2025-07-17T01:55:44Z',
#      'ordering': 1.0},
#     {'type': '003',
#      'location': '/carpicture01/pic4011/40110627_003.jpg',
#      'updatedDate': '2025-07-17T01:55:44Z',
#      'ordering': 3.0},
#     {'type': '004',
#      'location': '/carpicture01/pic4011/40110627_004.jpg',
#      'updatedDate': '2025-07-17T01:55:44Z',
#      'ordering': 4.0},
#     {'type': '007',
#      'location': '/carpicture01/pic4011/40110627_007.jpg',
#      'updatedDate': '2025-07-17T01:55:44Z',
#      'ordering': 7.0}],
#    'Manufacturer': '현대',
#    'Model': '그랜저 IG',
#    'Badge': '3.0 익스클루시브',
#    'BadgeDetail': '스페셜',
#    'GreenType': 'N',
#    'FuelType': '가솔린',
#    'Year': 201702.0,
#    'FormYear': '2017',
#    'Mileage': 43361.0,
#    'HomeServiceVerification': 'Y',
#    'ServiceCopyCar': 'DUPLICATION',
#    'Price': 2090.0,
#    'SellType': '일반',
#    'BuyType': ['Delivery'],
#    'OfficeCityState': '서울'},
#   {'Id': '40235078',
#    'Separation': ['B'],
#    'Trust': ['ExtendWarranty', 'HomeService'],
#    'ServiceMark': ['EncarMeetgo', 'EncarDiagnosisP1'],
#    'Condition': ['Inspection', 'Record', 'Resume'],
#    'Photo': '/carpicture02/pic4022/40225077_',
#    'Photos': [{'type': '001',
#      'location': '/carpicture02/pic4022/40225077_001.jpg',
#      'updatedDate': '2025-08-05T00:45:15Z',
#      'ordering': 1.0},
#     {'type': '003',
#      'location': '/carpicture02/pic4022/40225077_003.jpg',
#      'updatedDate': '2025-08-05T00:45:15Z',
#      'ordering': 3.0},
#     {'type': '004',
#      'location': '/carpicture02/pic4022/40225077_004.jpg',
#      'updatedDate': '2025-08-05T00:45:15Z',
#      'ordering': 4.0},
#     {'type': '007',
#      'location': '/carpicture02/pic4022/40225077_007.jpg',
#      'updatedDate': '2025-08-05T00:45:15Z',
#      'ordering': 7.0}],
#    'Manufacturer': '현대',
#    'Model': '더 뉴 그랜저 IG',
#    'Badge': '3.0 LPi (렌터카용)',
#    'BadgeDetail': '익스클루시브',
#    'GreenType': 'N',
#    'FuelType': 'LPG(일반인 구입)',
#    'Year': 202012.0,
#    'FormYear': '2021',
#    'Mileage': 127646.0,
#    'HomeServiceVerification': 'Y',
#    'ServiceCopyCar': 'DUPLICATION',
#    'Price': 2299.0,
#    'SellType': '일반',
#    'BuyType': ['Delivery'],
#    'OfficeCityState': '경기'},
#   {'Id': '40637315',
#    'Separation': ['B'],
#    'Trust': ['HomeService'],
#    'ServiceMark': ['EncarMeetgo', 'EncarDiagnosisP0'],
#    'Condition': ['Inspection', 'Record', 'Resume'],
#    'Photo': '/carpicture03/pic4063/40636267_',
#    'Photos': [{'type': '001',
#      'location': '/carpicture03/pic4063/40636267_001.jpg',
#      'updatedDate': '2025-09-26T07:39:50Z',
#      'ordering': 1.0},
#     {'type': '003',
#      'location': '/carpicture03/pic4063/40636267_003.jpg',
#      'updatedDate': '2025-09-26T07:39:50Z',
#      'ordering': 3.0},
#     {'type': '004',
#      'location': '/carpicture03/pic4063/40636267_004.jpg',
#      'updatedDate': '2025-09-26T07:39:50Z',
#      'ordering': 4.0},
#     {'type': '007',
#      'location': '/carpicture03/pic4063/40636267_007.jpg',
#      'updatedDate': '2025-09-26T07:39:50Z',
#      'ordering': 7.0}],
#    'Manufacturer': '현대',
#    'Model': '그랜저 HG',
#    'Badge': 'HG240 모던',
#    'GreenType': 'N',
#    'FuelType': '가솔린',
#    'Year': 201410.0,
#    'FormYear': '2015',
#    'Mileage': 20618.0,
#    'ServiceCopyCar': 'DUPLICATION',
#    'Price': 1400.0,
#    'SellType': '일반',
#    'BuyType': ['Delivery'],
#    'OfficeCityState': '경기'},
#   {'Id': '40283693',
#    'Separation': ['B'],
#    'Trust': ['HomeService'],
#    'ServiceMark': ['EncarMeetgo', 'EncarDiagnosisP1'],
#    'Condition': ['Inspection', 'Record', 'Resume'],
#    'Photo': '/carpicture07/pic4027/40276005_',
#    'Photos': [{'type': '001',
#      'location': '/carpicture07/pic4027/40276005_001.jpg',
#      'updatedDate': '2025-08-12T00:15:36Z',
#      'ordering': 1.0},
#     {'type': '003',
#      'location': '/carpicture07/pic4027/40276005_003.jpg',
#      'updatedDate': '2025-08-12T00:15:36Z',
#      'ordering': 3.0},
#     {'type': '004',
#      'location': '/carpicture07/pic4027/40276005_004.jpg',
#      'updatedDate': '2025-08-12T00:15:36Z',
#      'ordering': 4.0},
#     {'type': '007',
#      'location': '/carpicture07/pic4027/40276005_007.jpg',
#      'updatedDate': '2025-08-12T00:15:36Z',
#      'ordering': 7.0}],
#    'Manufacturer': '현대',
#    'Model': '그랜저 IG',
#    'Badge': '2.4 프리미엄',
#    'BadgeDetail': '스페셜',
#    'GreenType': 'N',
#    'FuelType': '가솔린',
#    'Year': 201701.0,
#    'FormYear': '2017',
#    'Mileage': 94720.0,
#    'HomeServiceVerification': 'Y',
#    'ServiceCopyCar': 'DUPLICATION',
#    'Price': 1459.0,
#    'SellType': '일반',
#    'BuyType': ['Delivery'],
#    'OfficeCityState': '경기'},
#   {'Id': '40070120',
#    'Separation': ['B'],
#    'Trust': ['ExtendWarranty', 'HomeService'],
#    'ServiceMark': ['EncarMeetgo', 'EncarDiagnosisP1'],
#    'Condition': ['Inspection', 'Record', 'Resume'],
#    'Photo': '/carpicture06/pic4006/40066830_',
#    'Photos': [{'type': '001',
#      'location': '/carpicture06/pic4006/40066830_001.jpg',
#      'updatedDate': '2025-07-11T01:15:35Z',
#      'ordering': 1.0},
#     {'type': '003',
#      'location': '/carpicture06/pic4006/40066830_003.jpg',
#      'updatedDate': '2025-07-11T01:15:35Z',
#      'ordering': 3.0},
#     {'type': '004',
#      'location': '/carpicture06/pic4006/40066830_004.jpg',
#      'updatedDate': '2025-07-11T01:15:35Z',
#      'ordering': 4.0},
#     {'type': '007',
#      'location': '/carpicture06/pic4006/40066830_007.jpg',
#      'updatedDate': '2025-07-11T01:15:35Z',
#      'ordering': 7.0}],
#    'Manufacturer': '현대',
#    'Model': '더 뉴 그랜저 IG',
#    'Badge': '3.0 LPi (렌터카용)',
#    'BadgeDetail': '프리미엄',
#    'GreenType': 'N',
#    'FuelType': 'LPG(일반인 구입)',
#    'Year': 202108.0,
#    'FormYear': '2022',
#    'Mileage': 55340.0,
#    'HomeServiceVerification': 'Y',
#    'ServiceCopyCar': 'DUPLICATION',
#    'Price': 2200.0,
#    'SellType': '일반',
#    'BuyType': ['Delivery'],
#    'OfficeCityState': '서울'},
#   {'Id': '39068750',
#    'Separation': ['B'],
#    'Trust': ['Warranty', 'ExtendWarranty'],
#    'ServiceMark': ['EncarDiagnosisP0'],
#    'Condition': ['Inspection', 'Record', 'Resume'],
#    'Photo': '/carpicture06/pic3906/39068750_',
#    'Photos': [{'type': '001',
#      'location': '/carpicture06/pic3906/39068750_001.jpg',
#      'updatedDate': '2025-02-19T01:43:57Z',
#      'ordering': 1.0},
#     {'type': '003',
#      'location': '/carpicture06/pic3906/39068750_003.jpg',
#      'updatedDate': '2025-02-19T01:43:57Z',
#      'ordering': 3.0},
#     {'type': '004',
#      'location': '/carpicture06/pic3906/39068750_004.jpg',
#      'updatedDate': '2025-02-19T01:43:57Z',
#      'ordering': 4.0},
#     {'type': '007',
#      'location': '/carpicture06/pic3906/39068750_007.jpg',
#      'updatedDate': '2025-02-19T01:43:57Z',
#      'ordering': 7.0}],
#    'Manufacturer': '현대',
#    'Model': '그랜저 IG',
#    'Badge': '2.4 프리미엄',
#    'BadgeDetail': '스페셜',
#    'GreenType': 'N',
#    'FuelType': '가솔린',
#    'Year': 201704.0,
#    'FormYear': '2018',
#    'Mileage': 48364.0,
#    'ServiceCopyCar': 'ORIGINAL',
#    'Price': 1850.0,
#    'SellType': '일반',
#    'BuyType': [],
#    'OfficeCityState': '서울'},
#   {'Id': '40428533',
#    'Separation': ['B'],
#    'Trust': ['Warranty'],
#    'ServiceMark': ['EncarDiagnosisP0'],
#    'Condition': ['Inspection', 'Record', 'Resume'],
#    'Photo': '/carpicture02/pic4042/40428533_',
#    'Photos': [{'type': '001',
#      'location': '/carpicture02/pic4042/40428533_001.jpg',
#      'updatedDate': '2025-09-02T03:32:03Z',
#      'ordering': 1.0},
#     {'type': '003',
#      'location': '/carpicture02/pic4042/40428533_003.jpg',
#      'updatedDate': '2025-09-02T03:32:03Z',
#      'ordering': 3.0},
#     {'type': '004',
#      'location': '/carpicture02/pic4042/40428533_004.jpg',
#      'updatedDate': '2025-09-02T03:32:03Z',
#      'ordering': 4.0},
#     {'type': '007',
#      'location': '/carpicture02/pic4042/40428533_007.jpg',
#      'updatedDate': '2025-09-02T03:32:03Z',
#      'ordering': 7.0}],
#    'Manufacturer': '현대',
#    'Model': '더 뉴 그랜저 IG',
#    'Badge': '2.5',
#    'BadgeDetail': '프리미엄',
#    'GreenType': 'N',
#    'FuelType': '가솔린',
#    'Year': 202207.0,
#    'FormYear': '2023',
#    'Mileage': 41188.0,
#    'ServiceCopyCar': 'ORIGINAL',
#    'Price': 2530.0,
#    'SellType': '일반',
#    'BuyType': [],
#    'OfficeCityState': '서울'},
#   {'Id': '40326679',
#    'Separation': ['B'],
#    'Trust': ['Warranty', 'ExtendWarranty'],
#    'ServiceMark': ['EncarDiagnosisP2'],
#    'Condition': ['Inspection', 'InspectionDirect', 'Record', 'Resume'],
#    'Photo': '/carpicture02/pic4032/40326679_',
#    'Photos': [{'type': '001',
#      'location': '/carpicture02/pic4032/40326679_027.jpg',
#      'updatedDate': '2025-08-19T06:15:04Z',
#      'ordering': 1.0},
#     {'type': '003',
#      'location': '/carpicture02/pic4032/40326679_003.jpg',
#      'updatedDate': '2025-08-19T06:15:04Z',
#      'ordering': 3.0},
#     {'type': '004',
#      'location': '/carpicture02/pic4032/40326679_004.jpg',
#      'updatedDate': '2025-08-19T06:15:04Z',
#      'ordering': 4.0},
#     {'type': '007',
#      'location': '/carpicture02/pic4032/40326679_007.jpg',
#      'updatedDate': '2025-08-19T06:15:04Z',
#      'ordering': 7.0}],
#    'Manufacturer': '현대',
#    'Model': '그랜저 IG',
#    'Badge': '2.4 프리미엄',
#    'BadgeDetail': '(세부등급 없음)',
#    'GreenType': 'N',
#    'FuelType': '가솔린',
#    'Year': 201711.0,
#    'FormYear': '2018',
#    'Mileage': 23786.0,
#    'ServiceCopyCar': 'ORIGINAL',
#    'Price': 1990.0,
#    'SellType': '일반',
#    'BuyType': [],
#    'OfficeCityState': '서울'},
#   {'Id': '37210233',
#    'Separation': ['B'],
#    'Trust': ['Warranty', 'ExtendWarranty'],
#    'ServiceMark': ['EncarDiagnosisP0'],
#    'Condition': ['Inspection', 'Record', 'Resume'],
#    'Photo': '/carpicture01/pic3721/37210233_',
#    'Photos': [{'type': '001',
#      'location': '/carpicture01/pic3721/37210233_001.jpg',
#      'updatedDate': '2024-04-19T06:20:57Z',
#      'ordering': 1.0},
#     {'type': '003',
#      'location': '/carpicture01/pic3721/37210233_003.jpg',
#      'updatedDate': '2024-04-19T06:20:57Z',
#      'ordering': 3.0},
#     {'type': '004',
#      'location': '/carpicture01/pic3721/37210233_004.jpg',
#      'updatedDate': '2024-04-19T06:20:57Z',
#      'ordering': 4.0},
#     {'type': '007',
#      'location': '/carpicture01/pic3721/37210233_007.jpg',
#      'updatedDate': '2024-04-19T06:20:57Z',
#      'ordering': 7.0}],
#    'Manufacturer': '현대',
#    'Model': '그랜저 하이브리드 (GN7)',
#    'Badge': '캘리그래피',
#    'GreenType': 'Y',
#    'EvType': '하이브리드',
#    'FuelType': '가솔린+전기',
#    'Year': 202301.0,
#    'FormYear': '2023',
#    'Mileage': 15199.0,
#    'ServiceCopyCar': 'ORIGINAL',
#    'Price': 4099.0,
#    'SellType': '일반',
#    'BuyType': [],
#    'OfficeCityState': '경기'},
#   {'Id': '40110627',
#    'Separation': ['B'],
#    'Trust': ['Warranty', 'ExtendWarranty'],
#    'ServiceMark': ['EncarDiagnosisP0'],
#    'Condition': ['Inspection', 'Record', 'Resume'],
#    'Photo': '/carpicture01/pic4011/40110627_',
#    'Photos': [{'type': '001',
#      'location': '/carpicture01/pic4011/40110627_001.jpg',
#      'updatedDate': '2025-07-17T01:55:44Z',
#      'ordering': 1.0},
#     {'type': '003',
#      'location': '/carpicture01/pic4011/40110627_003.jpg',
#      'updatedDate': '2025-07-17T01:55:44Z',
#      'ordering': 3.0},
#     {'type': '004',
#      'location': '/carpicture01/pic4011/40110627_004.jpg',
#      'updatedDate': '2025-07-17T01:55:44Z',
#      'ordering': 4.0},
#     {'type': '007',
#      'location': '/carpicture01/pic4011/40110627_007.jpg',
#      'updatedDate': '2025-07-17T01:55:44Z',
#      'ordering': 7.0}],
#    'Manufacturer': '현대',
#    'Model': '그랜저 IG',
#    'Badge': '3.0 익스클루시브',
#    'BadgeDetail': '스페셜',
#    'GreenType': 'N',
#    'FuelType': '가솔린',
#    'Year': 201702.0,
#    'FormYear': '2017',
#    'Mileage': 43361.0,
#    'ServiceCopyCar': 'ORIGINAL',
#    'Price': 2090.0,
#    'SellType': '일반',
#    'BuyType': [],
#    'OfficeCityState': '서울'},
#   {'Id': '40551146',
#    'Separation': ['B'],
#    'Trust': ['ExtendWarranty', 'HomeService'],
#    'ServiceMark': ['EncarMeetgo', 'EncarDiagnosisP1'],
#    'Condition': ['Inspection', 'Record', 'Resume'],
#    'Photo': '/carpicture03/pic4053/40537501_',
#    'Photos': [{'type': '001',
#      'location': '/carpicture03/pic4053/40537501_001.jpg',
#      'updatedDate': '2025-09-16T09:43:29Z',
#      'ordering': 1.0},
#     {'type': '003',
#      'location': '/carpicture03/pic4053/40537501_003.jpg',
#      'updatedDate': '2025-09-16T09:43:29Z',
#      'ordering': 3.0},
#     {'type': '004',
#      'location': '/carpicture03/pic4053/40537501_004.jpg',
#      'updatedDate': '2025-09-16T09:43:29Z',
#      'ordering': 4.0},
#     {'type': '007',
#      'location': '/carpicture03/pic4053/40537501_007.jpg',
#      'updatedDate': '2025-09-16T09:43:29Z',
#      'ordering': 7.0}],
#    'Manufacturer': '현대',
#    'Model': '더 뉴 그랜저 IG',
#    'Badge': '2.5',
#    'BadgeDetail': '르블랑',
#    'GreenType': 'N',
#    'FuelType': '가솔린',
#    'Year': 202111.0,
#    'FormYear': '2022',
#    'Mileage': 83425.0,
#    'HomeServiceVerification': 'Y',
#    'ServiceCopyCar': 'DUPLICATION',
#    'Price': 2630.0,
#    'SellType': '일반',
#    'BuyType': ['Delivery'],
#    'OfficeCityState': '경기'},
#   {'Id': '38619265',
#    'Separation': ['B'],
#    'Trust': [],
#    'ServiceMark': [],
#    'Condition': ['Inspection', 'Record', 'Resume'],
#    'Photo': '/carpicture01/pic3861/38619265_',
#    'Photos': [{'type': '001',
#      'location': '/carpicture01/pic3861/38619265_001.jpg',
#      'updatedDate': '2025-01-16T08:10:33Z',
#      'ordering': 1.0},
#     {'type': '003',
#      'location': '/carpicture01/pic3861/38619265_003.jpg',
#      'updatedDate': '2025-01-16T08:10:33Z',
#      'ordering': 3.0},
#     {'type': '004',
#      'location': '/carpicture01/pic3861/38619265_004.jpg',
#      'updatedDate': '2025-01-16T08:10:33Z',
#      'ordering': 4.0},
#     {'type': '007',
#      'location': '/carpicture01/pic3861/38619265_007.jpg',
#      'updatedDate': '2025-01-16T08:10:33Z',
#      'ordering': 7.0}],
#    'Manufacturer': '현대',
#    'Model': '뉴 그랜저 XG',
#    'Badge': 'S20',
#    'BadgeDetail': '기본형',
#    'GreenType': 'N',
#    'FuelType': '가솔린',
#    'Year': 200401.0,
#    'FormYear': '2004',
#    'Mileage': 232711.0,
#    'ServiceCopyCar': 'ORIGINAL',
#    'Price': 299.0,
#    'SellType': '일반',
#    'BuyType': [],
#    'OfficeCityState': '대구'},
#   {'Id': '40225077',
#    'Separation': ['B'],
#    'Trust': ['Warranty', 'ExtendWarranty'],
#    'ServiceMark': ['EncarDiagnosisP0'],
#    'Condition': ['Inspection', 'Record', 'Resume'],
#    'Photo': '/carpicture02/pic4022/40225077_',
#    'Photos': [{'type': '001',
#      'location': '/carpicture02/pic4022/40225077_001.jpg',
#      'updatedDate': '2025-08-05T00:45:15Z',
#      'ordering': 1.0},
#     {'type': '003',
#      'location': '/carpicture02/pic4022/40225077_003.jpg',
#      'updatedDate': '2025-08-05T00:45:15Z',
#      'ordering': 3.0},
#     {'type': '004',
#      'location': '/carpicture02/pic4022/40225077_004.jpg',
#      'updatedDate': '2025-08-05T00:45:15Z',
#      'ordering': 4.0},
#     {'type': '007',
#      'location': '/carpicture02/pic4022/40225077_007.jpg',
#      'updatedDate': '2025-08-05T00:45:15Z',
#      'ordering': 7.0}],
#    'Manufacturer': '현대',
#    'Model': '더 뉴 그랜저 IG',
#    'Badge': '3.0 LPi (렌터카용)',
#    'BadgeDetail': '익스클루시브',
#    'GreenType': 'N',
#    'FuelType': 'LPG(일반인 구입)',
#    'Year': 202012.0,
#    'FormYear': '2021',
#    'Mileage': 127646.0,
#    'ServiceCopyCar': 'ORIGINAL',
#    'Price': 2299.0,
#    'SellType': '일반',
#    'BuyType': [],
#    'OfficeCityState': '경기'},
#   {'Id': '39931058',
#    'Separation': ['B'],
#    'Trust': ['Warranty'],
#    'ServiceMark': ['EncarDiagnosisP0'],
#    'Condition': ['Inspection', 'Record', 'Resume'],
#    'Photo': '/carpicture03/pic3993/39931058_',
#    'Photos': [{'type': '001',
#      'location': '/carpicture03/pic3993/39931058_001.jpg',
#      'updatedDate': '2025-06-25T07:00:50Z',
#      'ordering': 1.0},
#     {'type': '003',
#      'location': '/carpicture03/pic3993/39931058_003.jpg',
#      'updatedDate': '2025-06-25T07:00:50Z',
#      'ordering': 3.0},
#     {'type': '004',
#      'location': '/carpicture03/pic3993/39931058_004.jpg',
#      'updatedDate': '2025-06-25T07:00:50Z',
#      'ordering': 4.0},
#     {'type': '007',
#      'location': '/carpicture03/pic3993/39931058_007.jpg',
#      'updatedDate': '2025-06-25T07:00:50Z',
#      'ordering': 7.0}],
#    'Manufacturer': '현대',
#    'Model': '더 뉴 그랜저 IG 하이브리드',
#    'Badge': '캘리그래피',
#    'GreenType': 'Y',
#    'EvType': '하이브리드',
#    'FuelType': '가솔린+전기',
#    'Year': 202010.0,
#    'FormYear': '2021',
#    'Mileage': 196044.0,
#    'ServiceCopyCar': 'ORIGINAL',
#    'Price': 1799.0,
#    'SellType': '일반',
#    'BuyType': [],
#    'OfficeCityState': '경기'},
#   {'Id': '40636267',
#    'Separation': ['B'],
#    'Trust': ['Warranty'],
#    'ServiceMark': ['EncarDiagnosisP0'],
#    'Condition': ['Inspection', 'Record', 'Resume'],
#    'Photo': '/carpicture03/pic4063/40636267_',
#    'Photos': [{'type': '001',
#      'location': '/carpicture03/pic4063/40636267_001.jpg',
#      'updatedDate': '2025-09-26T07:39:50Z',
#      'ordering': 1.0},
#     {'type': '003',
#      'location': '/carpicture03/pic4063/40636267_003.jpg',
#      'updatedDate': '2025-09-26T07:39:50Z',
#      'ordering': 3.0},
#     {'type': '004',
#      'location': '/carpicture03/pic4063/40636267_004.jpg',
#      'updatedDate': '2025-09-26T07:39:50Z',
#      'ordering': 4.0},
#     {'type': '007',
#      'location': '/carpicture03/pic4063/40636267_007.jpg',
#      'updatedDate': '2025-09-26T07:39:50Z',
#      'ordering': 7.0}],
#    'Manufacturer': '현대',
#    'Model': '그랜저 HG',
#    'Badge': 'HG240 모던',
#    'GreenType': 'N',
#    'FuelType': '가솔린',
#    'Year': 201410.0,
#    'FormYear': '2015',
#    'Mileage': 20618.0,
#    'ServiceCopyCar': 'ORIGINAL',
#    'Price': 1400.0,
#    'SellType': '일반',
#    'BuyType': [],
#    'OfficeCityState': '경기'},
#   {'Id': '40276005',
#    'Separation': ['B'],
#    'Trust': ['Warranty'],
#    'ServiceMark': ['EncarDiagnosisP0'],
#    'Condition': ['Inspection', 'Record', 'Resume'],
#    'Photo': '/carpicture07/pic4027/40276005_',
#    'Photos': [{'type': '001',
#      'location': '/carpicture07/pic4027/40276005_001.jpg',
#      'updatedDate': '2025-08-12T00:15:36Z',
#      'ordering': 1.0},
#     {'type': '003',
#      'location': '/carpicture07/pic4027/40276005_003.jpg',
#      'updatedDate': '2025-08-12T00:15:36Z',
#      'ordering': 3.0},
#     {'type': '004',
#      'location': '/carpicture07/pic4027/40276005_004.jpg',
#      'updatedDate': '2025-08-12T00:15:36Z',
#      'ordering': 4.0},
#     {'type': '007',
#      'location': '/carpicture07/pic4027/40276005_007.jpg',
#      'updatedDate': '2025-08-12T00:15:36Z',
#      'ordering': 7.0}],
#    'Manufacturer': '현대',
#    'Model': '그랜저 IG',
#    'Badge': '2.4 프리미엄',
#    'BadgeDetail': '스페셜',
#    'GreenType': 'N',
#    'FuelType': '가솔린',
#    'Year': 201701.0,
#    'FormYear': '2017',
#    'Mileage': 94720.0,
#    'ServiceCopyCar': 'ORIGINAL',
#    'Price': 1459.0,
#    'SellType': '일반',
#    'BuyType': [],
#    'OfficeCityState': '경기'},
#   {'Id': '40066830',
#    'Separation': ['B'],
#    'Trust': ['Warranty', 'ExtendWarranty'],
#    'ServiceMark': ['EncarDiagnosisP0'],
#    'Condition': ['Inspection', 'Record', 'Resume'],
#    'Photo': '/carpicture06/pic4006/40066830_',
#    'Photos': [{'type': '001',
#      'location': '/carpicture06/pic4006/40066830_001.jpg',
#      'updatedDate': '2025-07-11T01:15:35Z',
#      'ordering': 1.0},
#     {'type': '003',
#      'location': '/carpicture06/pic4006/40066830_003.jpg',
#      'updatedDate': '2025-07-11T01:15:35Z',
#      'ordering': 3.0},
#     {'type': '004',
#      'location': '/carpicture06/pic4006/40066830_004.jpg',
#      'updatedDate': '2025-07-11T01:15:35Z',
#      'ordering': 4.0},
#     {'type': '007',
#      'location': '/carpicture06/pic4006/40066830_007.jpg',
#      'updatedDate': '2025-07-11T01:15:35Z',
#      'ordering': 7.0}],
#    'Manufacturer': '현대',
#    'Model': '더 뉴 그랜저 IG',
#    'Badge': '3.0 LPi (렌터카용)',
#    'BadgeDetail': '프리미엄',
#    'GreenType': 'N',
#    'FuelType': 'LPG(일반인 구입)',
#    'Year': 202108.0,
#    'FormYear': '2022',
#    'Mileage': 55340.0,
#    'ServiceCopyCar': 'ORIGINAL',
#    'Price': 2200.0,
#    'SellType': '일반',
#    'BuyType': [],
#    'OfficeCityState': '서울'},
#   {'Id': '39864802',
#    'Separation': ['B'],
#    'Trust': [],
#    'ServiceMark': [],
#    'Condition': [],
#    'Photo': '/carpicture06/pic3986/39864802_',
#    'Photos': [{'type': '001',
#      'location': '/carpicture06/pic3986/39864802_001.jpg',
#      'updatedDate': '2025-08-30T23:37:55Z',
#      'ordering': 1.0},
#     {'type': '003',
#      'location': '/carpicture06/pic3986/39864802_003.jpg',
#      'updatedDate': '2025-08-30T23:37:55Z',
#      'ordering': 3.0},
#     {'type': '004',
#      'location': '/carpicture06/pic3986/39864802_004.jpg',
#      'updatedDate': '2025-08-30T23:37:55Z',
#      'ordering': 4.0},
#     {'type': '007',
#      'location': '/carpicture06/pic3986/39864802_007.jpg',
#      'updatedDate': '2025-08-30T23:37:55Z',
#      'ordering': 7.0}],
#    'Manufacturer': '현대',
#    'Model': '그랜저 HG',
#    'Badge': 'LPG HG300 익스클루시브',
#    'GreenType': 'N',
#    'FuelType': 'LPG(일반인 구입)',
#    'Year': 201410.0,
#    'FormYear': '2015',
#    'Mileage': 342411.0,
#    'ServiceCopyCar': 'ORIGINAL',
#    'Price': 449.0,
#    'SellType': '일반',
#    'BuyType': [],
#    'OfficeCityState': '대구'},
#   {'Id': '39572011',
#    'Separation': ['B'],
#    'Trust': [],
#    'ServiceMark': [],
#    'Condition': ['Inspection', 'Record', 'Resume'],
#    'Photo': '/carpicture07/pic3957/39572011_',
#    'Photos': [{'type': '001',
#      'location': '/carpicture07/pic3957/39572011_001.jpg',
#      'updatedDate': '2025-05-07T05:51:21Z',
#      'ordering': 1.0},
#     {'type': '003',
#      'location': '/carpicture07/pic3957/39572011_003.jpg',
#      'updatedDate': '2025-05-07T05:51:21Z',
#      'ordering': 3.0},
#     {'type': '004',
#      'location': '/carpicture07/pic3957/39572011_004.jpg',
#      'updatedDate': '2025-05-07T05:51:21Z',
#      'ordering': 4.0},
#     {'type': '007',
#      'location': '/carpicture07/pic3957/39572011_007.jpg',
#      'updatedDate': '2025-05-07T05:51:21Z',
#      'ordering': 7.0}],
#    'Manufacturer': '현대',
#    'Model': '그랜저 HG',
#    'Badge': 'HG240 모던',
#    'GreenType': 'N',
#    'FuelType': '가솔린',
#    'Year': 201405.0,
#    'FormYear': '2014',
#    'Mileage': 119266.0,
#    'ServiceCopyCar': 'ORIGINAL',
#    'Price': 590.0,
#    'SellType': '일반',
#    'BuyType': [],
#    'OfficeCityState': '경기'},
#   {'Id': '40537501',
#    'Separation': ['B'],
#    'Trust': ['Warranty', 'ExtendWarranty'],
#    'ServiceMark': ['EncarDiagnosisP0'],
#    'Condition': ['Inspection', 'Record', 'Resume'],
#    'Photo': '/carpicture03/pic4053/40537501_',
#    'Photos': [{'type': '001',
#      'location': '/carpicture03/pic4053/40537501_001.jpg',
#      'updatedDate': '2025-09-16T09:43:29Z',
#      'ordering': 1.0},
#     {'type': '003',
#      'location': '/carpicture03/pic4053/40537501_003.jpg',
#      'updatedDate': '2025-09-16T09:43:29Z',
#      'ordering': 3.0},
#     {'type': '004',
#      'location': '/carpicture03/pic4053/40537501_004.jpg',
#      'updatedDate': '2025-09-16T09:43:29Z',
#      'ordering': 4.0},
#     {'type': '007',
#      'location': '/carpicture03/pic4053/40537501_007.jpg',
#      'updatedDate': '2025-09-16T09:43:29Z',
#      'ordering': 7.0}],
#    'Manufacturer': '현대',
#    'Model': '더 뉴 그랜저 IG',
#    'Badge': '2.5',
#    'BadgeDetail': '르블랑',
#    'GreenType': 'N',
#    'FuelType': '가솔린',
#    'Year': 202111.0,
#    'FormYear': '2022',
#    'Mileage': 83425.0,
#    'ServiceCopyCar': 'ORIGINAL',
#    'Price': 2630.0,
#    'SellType': '일반',
#    'BuyType': [],
#    'OfficeCityState': '경기'},
#   {'Id': '40185399',
#    'Separation': ['B'],
#    'Trust': ['HomeService', 'Meetgo'],
#    'ServiceMark': ['EncarMeetgo', 'EncarDiagnosisP1'],
#    'Condition': ['Inspection', 'InspectionDirect', 'Record', 'Resume'],
#    'Photo': '/carpicture08/pic4018/40185383_',
#    'Photos': [{'type': '001',
#      'location': '/carpicture08/pic4018/40185383_001.jpg',
#      'updatedDate': '2025-07-29T05:29:42Z',
#      'ordering': 1.0},
#     {'type': '003',
#      'location': '/carpicture08/pic4018/40185383_003.jpg',
#      'updatedDate': '2025-07-29T05:29:42Z',
#      'ordering': 3.0},
#     {'type': '004',
#      'location': '/carpicture08/pic4018/40185383_004.jpg',
#      'updatedDate': '2025-07-29T05:29:42Z',
#      'ordering': 4.0},
#     {'type': '007',
#      'location': '/carpicture08/pic4018/40185383_007.jpg',
#      'updatedDate': '2025-07-29T05:29:42Z',
#      'ordering': 7.0}],
#    'Manufacturer': '현대',
#    'Model': '더 뉴 그랜저 IG',
#    'Badge': '2.5',
#    'BadgeDetail': '프리미엄',
#    'GreenType': 'N',
#    'FuelType': '가솔린',
#    'Year': 202206.0,
#    'FormYear': '2023',
#    'Mileage': 34677.0,
#    'HomeServiceVerification': 'Y',
#    'ServiceCopyCar': 'DUPLICATION',
#    'Price': 2590.0,
#    'SellType': '일반',
#    'BuyType': ['Delivery', 'Visit'],
#    'OfficeCityState': '경기',
#    'IsSingleAd': 'Y'},
#   {'Id': '40194734',
#    'Separation': ['B'],
#    'Trust': ['HomeService'],
#    'ServiceMark': ['EncarMeetgo', 'EncarDiagnosisP1'],
#    'Condition': ['Inspection', 'Record', 'Resume'],
#    'Photo': '/carpicture08/pic4018/40183039_',
#    'Photos': [{'type': '001',
#      'location': '/carpicture08/pic4018/40183039_001.jpg',
#      'updatedDate': '2025-07-29T05:18:02Z',
#      'ordering': 1.0},
#     {'type': '003',
#      'location': '/carpicture08/pic4018/40183039_003.jpg',
#      'updatedDate': '2025-07-29T05:18:02Z',
#      'ordering': 3.0},
#     {'type': '004',
#      'location': '/carpicture08/pic4018/40183039_004.jpg',
#      'updatedDate': '2025-07-29T05:18:02Z',
#      'ordering': 4.0},
#     {'type': '007',
#      'location': '/carpicture08/pic4018/40183039_007.jpg',
#      'updatedDate': '2025-07-29T05:18:02Z',
#      'ordering': 7.0}],
#    'Manufacturer': '현대',
#    'Model': '더 뉴 그랜저 IG',
#    'Badge': '3.3',
#    'BadgeDetail': '캘리그래피',
#    'GreenType': 'N',
#    'FuelType': '가솔린',
#    'Year': 202001.0,
#    'FormYear': '2020',
#    'Mileage': 75089.0,
#    'HomeServiceVerification': 'Y',
#    'ServiceCopyCar': 'DUPLICATION',
#    'Price': 2420.0,
#    'SellType': '일반',
#    'BuyType': ['Delivery'],
#    'OfficeCityState': '경기'},
#   {'Id': '40267359',
#    'Separation': ['B'],
#    'Trust': ['ExtendWarranty', 'HomeService'],
#    'ServiceMark': ['EncarMeetgo', 'EncarDiagnosisP1'],
#    'Condition': ['Inspection', 'Record', 'Resume'],
#    'Photo': '/carpicture06/pic4026/40264670_',
#    'Photos': [{'type': '001',
#      'location': '/carpicture06/pic4026/40264670_001.jpg',
#      'updatedDate': '2025-08-08T07:29:38Z',
#      'ordering': 1.0},
#     {'type': '003',
#      'location': '/carpicture06/pic4026/40264670_003.jpg',
#      'updatedDate': '2025-08-08T07:29:38Z',
#      'ordering': 3.0},
#     {'type': '004',
#      'location': '/carpicture06/pic4026/40264670_004.jpg',
#      'updatedDate': '2025-08-08T07:29:38Z',
#      'ordering': 4.0},
#     {'type': '007',
#      'location': '/carpicture06/pic4026/40264670_007.jpg',
#      'updatedDate': '2025-08-08T07:29:38Z',
#      'ordering': 7.0}],
#    'Manufacturer': '현대',
#    'Model': '더 뉴 그랜저 IG',
#    'Badge': '3.0 LPi (렌터카용)',
#    'BadgeDetail': '모던',
#    'GreenType': 'N',
#    'FuelType': 'LPG(일반인 구입)',
#    'Year': 202110.0,
#    'FormYear': '2022',
#    'Mileage': 68117.0,
#    'HomeServiceVerification': 'Y',
#    'ServiceCopyCar': 'DUPLICATION',
#    'Price': 2250.0,
#    'SellType': '일반',
#    'BuyType': ['Delivery'],
#    'OfficeCityState': '서울'},
#   {'Id': '40187389',
#    'Separation': ['B'],
#    'Trust': ['ExtendWarranty', 'HomeService'],
#    'ServiceMark': ['EncarMeetgo', 'EncarDiagnosisP1'],
#    'Condition': ['Inspection', 'Record', 'Resume'],
#    'Photo': '/carpicture08/pic4018/40186046_',
#    'Photos': [{'type': '001',
#      'location': '/carpicture08/pic4018/40186046_001.jpg',
#      'updatedDate': '2025-07-28T08:20:19Z',
#      'ordering': 1.0},
#     {'type': '003',
#      'location': '/carpicture08/pic4018/40186046_003.jpg',
#      'updatedDate': '2025-07-28T08:20:19Z',
#      'ordering': 3.0},
#     {'type': '004',
#      'location': '/carpicture08/pic4018/40186046_004.jpg',
#      'updatedDate': '2025-07-28T08:20:19Z',
#      'ordering': 4.0},
#     {'type': '007',
#      'location': '/carpicture08/pic4018/40186046_007.jpg',
#      'updatedDate': '2025-07-28T08:20:19Z',
#      'ordering': 7.0}],
#    'Manufacturer': '현대',
#    'Model': '그랜저 (GN7)',
#    'Badge': '3.5 LPG 2WD',
#    'BadgeDetail': '프리미엄',
#    'GreenType': 'N',
#    'FuelType': 'LPG(일반인 구입)',
#    'Year': 202303.0,
#    'FormYear': '2023',
#    'Mileage': 41281.0,
#    'HomeServiceVerification': 'Y',
#    'ServiceCopyCar': 'DUPLICATION',
#    'Price': 2899.0,
#    'SellType': '일반',
#    'BuyType': ['Delivery'],
#    'OfficeCityState': '경기'},
#   {'Id': '40246928',
#    'Separation': ['B'],
#    'Trust': ['ExtendWarranty', 'HomeService'],
#    'ServiceMark': ['EncarMeetgo', 'EncarDiagnosisP1'],
#    'Condition': ['Inspection', 'Record', 'Resume'],
#    'Photo': '/carpicture03/pic4023/40234628_',
#    'Photos': [{'type': '001',
#      'location': '/carpicture03/pic4023/40234628_001.jpg',
#      'updatedDate': '2025-08-06T04:46:05Z',
#      'ordering': 1.0},
#     {'type': '003',
#      'location': '/carpicture03/pic4023/40234628_003.jpg',
#      'updatedDate': '2025-08-06T04:46:05Z',
#      'ordering': 3.0},
#     {'type': '004',
#      'location': '/carpicture03/pic4023/40234628_004.jpg',
#      'updatedDate': '2025-08-06T04:46:05Z',
#      'ordering': 4.0},
#     {'type': '007',
#      'location': '/carpicture03/pic4023/40234628_007.jpg',
#      'updatedDate': '2025-08-06T04:46:05Z',
#      'ordering': 7.0}],
#    'Manufacturer': '현대',
#    'Model': '그랜저 하이브리드 (GN7)',
#    'Badge': '캘리그래피',
#    'GreenType': 'Y',
#    'EvType': '하이브리드',
#    'FuelType': '가솔린+전기',
#    'Year': 202302.0,
#    'FormYear': '2023',
#    'Mileage': 17816.0,
#    'HomeServiceVerification': 'Y',
#    'ServiceCopyCar': 'DUPLICATION',
#    'Price': 4100.0,
#    'SellType': '일반',
#    'BuyType': ['Delivery'],
#    'OfficeCityState': '서울'},
#   {'Id': '40011710',
#    'Separation': ['B'],
#    'Trust': ['ExtendWarranty', 'HomeService'],
#    'ServiceMark': ['EncarMeetgo', 'EncarDiagnosisP1'],
#    'Condition': ['Inspection', 'Record', 'Resume'],
#    'Photo': '/carpicture01/pic4001/40010873_',
#    'Photos': [{'type': '001',
#      'location': '/carpicture01/pic4001/40010873_001.jpg',
#      'updatedDate': '2025-07-03T06:28:08Z',
#      'ordering': 1.0},
#     {'type': '003',
#      'location': '/carpicture01/pic4001/40010873_003.jpg',
#      'updatedDate': '2025-07-03T06:28:08Z',
#      'ordering': 3.0},
#     {'type': '004',
#      'location': '/carpicture01/pic4001/40010873_004.jpg',
#      'updatedDate': '2025-07-03T06:28:08Z',
#      'ordering': 4.0},
#     {'type': '007',
#      'location': '/carpicture01/pic4001/40010873_007.jpg',
#      'updatedDate': '2025-07-03T06:28:08Z',
#      'ordering': 7.0}],
#    'Manufacturer': '현대',
#    'Model': '더 뉴 그랜저 IG',
#    'Badge': '2.5',
#    'BadgeDetail': '익스클루시브',
#    'GreenType': 'N',
#    'FuelType': '가솔린',
#    'Year': 202206.0,
#    'FormYear': '2023',
#    'Mileage': 34009.0,
#    'HomeServiceVerification': 'Y',
#    'ServiceCopyCar': 'DUPLICATION',
#    'Price': 2830.0,
#    'SellType': '일반',
#    'BuyType': ['Delivery'],
#    'OfficeCityState': '서울'},
#   {'Id': '40183039',
#    'Separation': ['B'],
#    'Trust': ['Warranty'],
#    'ServiceMark': ['EncarDiagnosisP0'],
#    'Condition': ['Inspection', 'Record', 'Resume'],
#    'Photo': '/carpicture08/pic4018/40183039_',
#    'Photos': [{'type': '001',
#      'location': '/carpicture08/pic4018/40183039_001.jpg',
#      'updatedDate': '2025-07-29T05:18:02Z',
#      'ordering': 1.0},
#     {'type': '003',
#      'location': '/carpicture08/pic4018/40183039_003.jpg',
#      'updatedDate': '2025-07-29T05:18:02Z',
#      'ordering': 3.0},
#     {'type': '004',
#      'location': '/carpicture08/pic4018/40183039_004.jpg',
#      'updatedDate': '2025-07-29T05:18:02Z',
#      'ordering': 4.0},
#     {'type': '007',
#      'location': '/carpicture08/pic4018/40183039_007.jpg',
#      'updatedDate': '2025-07-29T05:18:02Z',
#      'ordering': 7.0}],
#    'Manufacturer': '현대',
#    'Model': '더 뉴 그랜저 IG',
#    'Badge': '3.3',
#    'BadgeDetail': '캘리그래피',
#    'GreenType': 'N',
#    'FuelType': '가솔린',
#    'Year': 202001.0,
#    'FormYear': '2020',
#    'Mileage': 75089.0,
#    'ServiceCopyCar': 'ORIGINAL',
#    'Price': 2420.0,
#    'SellType': '일반',
#    'BuyType': [],
#    'OfficeCityState': '경기'},
#   {'Id': '40264670',
#    'Separation': ['B'],
#    'Trust': ['Warranty', 'ExtendWarranty'],
#    'ServiceMark': ['EncarDiagnosisP0'],
#    'Condition': ['Inspection', 'Record', 'Resume'],
#    'Photo': '/carpicture06/pic4026/40264670_',
#    'Photos': [{'type': '001',
#      'location': '/carpicture06/pic4026/40264670_001.jpg',
#      'updatedDate': '2025-08-08T07:29:38Z',
#      'ordering': 1.0},
#     {'type': '003',
#      'location': '/carpicture06/pic4026/40264670_003.jpg',
#      'updatedDate': '2025-08-08T07:29:38Z',
#      'ordering': 3.0},
#     {'type': '004',
#      'location': '/carpicture06/pic4026/40264670_004.jpg',
#      'updatedDate': '2025-08-08T07:29:38Z',
#      'ordering': 4.0},
#     {'type': '007',
#      'location': '/carpicture06/pic4026/40264670_007.jpg',
#      'updatedDate': '2025-08-08T07:29:38Z',
#      'ordering': 7.0}],
#    'Manufacturer': '현대',
#    'Model': '더 뉴 그랜저 IG',
#    'Badge': '3.0 LPi (렌터카용)',
#    'BadgeDetail': '모던',
#    'GreenType': 'N',
#    'FuelType': 'LPG(일반인 구입)',
#    'Year': 202110.0,
#    'FormYear': '2022',
#    'Mileage': 68117.0,
#    'ServiceCopyCar': 'ORIGINAL',
#    'Price': 2250.0,
#    'SellType': '일반',
#    'BuyType': [],
#    'OfficeCityState': '서울'},
#   {'Id': '40408651',
#    'Separation': ['B'],
#    'Trust': ['Warranty'],
#    'ServiceMark': ['EncarDiagnosisP0'],
#    'Condition': ['Inspection', 'Record', 'Resume'],
#    'Photo': '/carpicture10/pic4040/40408651_',
#    'Photos': [{'type': '001',
#      'location': '/carpicture10/pic4040/40408651_001.jpg',
#      'updatedDate': '2025-09-01T01:28:21Z',
#      'ordering': 1.0},
#     {'type': '003',
#      'location': '/carpicture10/pic4040/40408651_003.jpg',
#      'updatedDate': '2025-09-01T01:28:21Z',
#      'ordering': 3.0},
#     {'type': '004',
#      'location': '/carpicture10/pic4040/40408651_004.jpg',
#      'updatedDate': '2025-09-01T01:28:21Z',
#      'ordering': 4.0},
#     {'type': '007',
#      'location': '/carpicture10/pic4040/40408651_007.jpg',
#      'updatedDate': '2025-09-01T01:28:21Z',
#      'ordering': 7.0}],
#    'Manufacturer': '현대',
#    'Model': '그랜저 HG',
#    'Badge': 'HG300 노블',
#    'GreenType': 'N',
#    'FuelType': '가솔린',
#    'Year': 201210.0,
#    'FormYear': '2012',
#    'Mileage': 122420.0,
#    'ServiceCopyCar': 'ORIGINAL',
#    'Price': 579.0,
#    'SellType': '일반',
#    'BuyType': [],
#    'OfficeCityState': '대구'},
#   {'Id': '39723646',
#    'Separation': ['B'],
#    'Trust': ['Warranty'],
#    'ServiceMark': ['EncarDiagnosisP0'],
#    'Condition': ['Inspection', 'Record'],
#    'Photo': '/carpicture02/pic3972/39723646_',
#    'Photos': [{'type': '001',
#      'location': '/carpicture02/pic3972/39723646_001.jpg',
#      'updatedDate': '2025-05-26T04:34:49Z',
#      'ordering': 1.0},
#     {'type': '003',
#      'location': '/carpicture02/pic3972/39723646_003.jpg',
#      'updatedDate': '2025-05-26T04:34:49Z',
#      'ordering': 3.0},
#     {'type': '004',
#      'location': '/carpicture02/pic3972/39723646_004.jpg',
#      'updatedDate': '2025-05-26T04:34:49Z',
#      'ordering': 4.0},
#     {'type': '007',
#      'location': '/carpicture02/pic3972/39723646_007.jpg',
#      'updatedDate': '2025-05-26T04:34:49Z',
#      'ordering': 7.0}],
#    'Manufacturer': '현대',
#    'Model': '그랜저 HG',
#    'Badge': 'HG220 디젤 모던',
#    'GreenType': 'N',
#    'FuelType': '디젤',
#    'Year': 201408.0,
#    'FormYear': '2015',
#    'Mileage': 139224.0,
#    'ServiceCopyCar': 'ORIGINAL',
#    'Price': 659.0,
#    'SellType': '일반',
#    'BuyType': [],
#    'OfficeCityState': '대구'},
#   {'Id': '40631603',
#    'Separation': ['B'],
#    'Trust': [],
#    'ServiceMark': [],
#    'Condition': ['Inspection', 'Record', 'Resume'],
#    'Photo': '/carpicture03/pic4063/40631603_',
#    'Photos': [{'type': '001',
#      'location': '/carpicture03/pic4063/40631603_001.jpg',
#      'updatedDate': '2025-09-26T06:00:18Z',
#      'ordering': 1.0},
#     {'type': '003',
#      'location': '/carpicture03/pic4063/40631603_003.jpg',
#      'updatedDate': '2025-09-26T06:00:18Z',
#      'ordering': 3.0},
#     {'type': '004',
#      'location': '/carpicture03/pic4063/40631603_004.jpg',
#      'updatedDate': '2025-09-26T06:00:18Z',
#      'ordering': 4.0},
#     {'type': '007',
#      'location': '/carpicture03/pic4063/40631603_007.jpg',
#      'updatedDate': '2025-09-26T06:00:18Z',
#      'ordering': 7.0}],
#    'Manufacturer': '현대',
#    'Model': '그랜저 HG 하이브리드',
#    'Badge': '프리미엄',
#    'GreenType': 'Y',
#    'EvType': '하이브리드',
#    'FuelType': '가솔린+전기',
#    'Year': 201405.0,
#    'FormYear': '2015',
#    'Mileage': 134004.0,
#    'ServiceCopyCar': 'ORIGINAL',
#    'Price': 840.0,
#    'SellType': '일반',
#    'BuyType': [],
#    'OfficeCityState': '대구'},
#   {'Id': '40186046',
#    'Separation': ['B'],
#    'Trust': ['Warranty', 'ExtendWarranty'],
#    'ServiceMark': ['EncarDiagnosisP0'],
#    'Condition': ['Inspection', 'Record', 'Resume'],
#    'Photo': '/carpicture08/pic4018/40186046_',
#    'Photos': [{'type': '001',
#      'location': '/carpicture08/pic4018/40186046_001.jpg',
#      'updatedDate': '2025-07-28T08:20:19Z',
#      'ordering': 1.0},
#     {'type': '003',
#      'location': '/carpicture08/pic4018/40186046_003.jpg',
#      'updatedDate': '2025-07-28T08:20:19Z',
#      'ordering': 3.0},
#     {'type': '004',
#      'location': '/carpicture08/pic4018/40186046_004.jpg',
#      'updatedDate': '2025-07-28T08:20:19Z',
#      'ordering': 4.0},
#     {'type': '007',
#      'location': '/carpicture08/pic4018/40186046_007.jpg',
#      'updatedDate': '2025-07-28T08:20:19Z',
#      'ordering': 7.0}],
#    'Manufacturer': '현대',
#    'Model': '그랜저 (GN7)',
#    'Badge': '3.5 LPG 2WD',
#    'BadgeDetail': '프리미엄',
#    'GreenType': 'N',
#    'FuelType': 'LPG(일반인 구입)',
#    'Year': 202303.0,
#    'FormYear': '2023',
#    'Mileage': 41281.0,
#    'ServiceCopyCar': 'ORIGINAL',
#    'Price': 2899.0,
#    'SellType': '일반',
#    'BuyType': [],
#    'OfficeCityState': '경기'},
#   {'Id': '40234628',
#    'Separation': ['B'],
#    'Trust': ['Warranty', 'ExtendWarranty'],
#    'ServiceMark': ['EncarDiagnosisP0'],
#    'Condition': ['Inspection', 'Record', 'Resume'],
#    'Photo': '/carpicture03/pic4023/40234628_',
#    'Photos': [{'type': '001',
#      'location': '/carpicture03/pic4023/40234628_001.jpg',
#      'updatedDate': '2025-08-06T04:46:05Z',
#      'ordering': 1.0},
#     {'type': '003',
#      'location': '/carpicture03/pic4023/40234628_003.jpg',
#      'updatedDate': '2025-08-06T04:46:05Z',
#      'ordering': 3.0},
#     {'type': '004',
#      'location': '/carpicture03/pic4023/40234628_004.jpg',
#      'updatedDate': '2025-08-06T04:46:05Z',
#      'ordering': 4.0},
#     {'type': '007',
#      'location': '/carpicture03/pic4023/40234628_007.jpg',
#      'updatedDate': '2025-08-06T04:46:05Z',
#      'ordering': 7.0}],
#    'Manufacturer': '현대',
#    'Model': '그랜저 하이브리드 (GN7)',
#    'Badge': '캘리그래피',
#    'GreenType': 'Y',
#    'EvType': '하이브리드',
#    'FuelType': '가솔린+전기',
#    'Year': 202302.0,
#    'FormYear': '2023',
#    'Mileage': 17816.0,
#    'ServiceCopyCar': 'ORIGINAL',
#    'Price': 4100.0,
#    'SellType': '일반',
#    'BuyType': [],
#    'OfficeCityState': '서울'},
#   {'Id': '40010873',
#    'Separation': ['B'],
#    'Trust': ['Warranty', 'ExtendWarranty'],
#    'ServiceMark': ['EncarDiagnosisP0'],
#    'Condition': ['Inspection', 'Record', 'Resume'],
#    'Photo': '/carpicture01/pic4001/40010873_',
#    'Photos': [{'type': '001',
#      'location': '/carpicture01/pic4001/40010873_001.jpg',
#      'updatedDate': '2025-07-03T06:28:08Z',
#      'ordering': 1.0},
#     {'type': '003',
#      'location': '/carpicture01/pic4001/40010873_003.jpg',
#      'updatedDate': '2025-07-03T06:28:08Z',
#      'ordering': 3.0},
#     {'type': '004',
#      'location': '/carpicture01/pic4001/40010873_004.jpg',
#      'updatedDate': '2025-07-03T06:28:08Z',
#      'ordering': 4.0},
#     {'type': '007',
#      'location': '/carpicture01/pic4001/40010873_007.jpg',
#      'updatedDate': '2025-07-03T06:28:08Z',
#      'ordering': 7.0}],
#    'Manufacturer': '현대',
#    'Model': '더 뉴 그랜저 IG',
#    'Badge': '2.5',
#    'BadgeDetail': '익스클루시브',
#    'GreenType': 'N',
#    'FuelType': '가솔린',
#    'Year': 202206.0,
#    'FormYear': '2023',
#    'Mileage': 34009.0,
#    'ServiceCopyCar': 'ORIGINAL',
#    'Price': 2830.0,
#    'SellType': '일반',
#    'BuyType': [],
#    'OfficeCityState': '서울'},
#   {'Id': '38295029',
#    'Separation': ['B'],
#    'Trust': [],
#    'ServiceMark': [],
#    'Condition': ['Inspection', 'Record', 'Resume'],
#    'Photo': '/carpicture09/pic3829/38295029_',
#    'Photos': [{'type': '001',
#      'location': '/carpicture09/pic3829/38295029_001.jpg',
#      'updatedDate': '2025-08-08T03:35:35Z',
#      'ordering': 1.0},
#     {'type': '003',
#      'location': '/carpicture09/pic3829/38295029_003.jpg',
#      'updatedDate': '2025-08-08T03:35:35Z',
#      'ordering': 3.0},
#     {'type': '004',
#      'location': '/carpicture09/pic3829/38295029_004.jpg',
#      'updatedDate': '2025-08-08T03:35:35Z',
#      'ordering': 4.0},
#     {'type': '007',
#      'location': '/carpicture09/pic3829/38295029_007.jpg',
#      'updatedDate': '2025-08-08T03:35:35Z',
#      'ordering': 7.0}],
#    'Manufacturer': '현대',
#    'Model': '더 뉴 그랜저 IG',
#    'Badge': '2.5',
#    'BadgeDetail': '프리미엄',
#    'GreenType': 'N',
#    'FuelType': '가솔린',
#    'Year': 202202.0,
#    'FormYear': '2022',
#    'Mileage': 57063.0,
#    'ServiceCopyCar': 'ORIGINAL',
#    'Price': 2300.0,
#    'SellType': '일반',
#    'BuyType': [],
#    'OfficeCityState': '인천'},
#   {'Id': '40276229',
#    'Separation': ['B'],
#    'Trust': ['Warranty', 'ExtendWarranty'],
#    'ServiceMark': ['EncarDiagnosisP0'],
#    'Condition': ['Inspection', 'Record', 'Resume'],
#    'Photo': '/carpicture07/pic4027/40276229_',
#    'Photos': [{'type': '001',
#      'location': '/carpicture07/pic4027/40276229_001.jpg',
#      'updatedDate': '2025-08-11T06:43:06Z',
#      'ordering': 1.0},
#     {'type': '003',
#      'location': '/carpicture07/pic4027/40276229_003.jpg',
#      'updatedDate': '2025-08-11T06:43:06Z',
#      'ordering': 3.0},
#     {'type': '004',
#      'location': '/carpicture07/pic4027/40276229_004.jpg',
#      'updatedDate': '2025-08-11T06:43:06Z',
#      'ordering': 4.0},
#     {'type': '007',
#      'location': '/carpicture07/pic4027/40276229_007.jpg',
#      'updatedDate': '2025-08-11T06:43:06Z',
#      'ordering': 7.0}],
#    'Manufacturer': '현대',
#    'Model': '더 뉴 그랜저 IG',
#    'Badge': '2.5',
#    'BadgeDetail': '익스클루시브',
#    'GreenType': 'N',
#    'FuelType': '가솔린',
#    'Year': 202008.0,
#    'FormYear': '2020',
#    'Mileage': 91031.0,
#    'ServiceCopyCar': 'ORIGINAL',
#    'Price': 2320.0,
#    'SellType': '일반',
#    'BuyType': [],
#    'OfficeCityState': '대구'},
#   {'Id': '39245390',
#    'Separation': ['B'],
#    'Trust': ['ExtendWarranty', 'HomeService'],
#    'ServiceMark': ['EncarMeetgo', 'EncarDiagnosisP1'],
#    'Condition': ['Inspection', 'Record', 'Resume'],
#    'Photo': '/carpicture04/pic3924/39244068_',
#    'Photos': [{'type': '001',
#      'location': '/carpicture04/pic3924/39244068_001.jpg',
#      'updatedDate': '2025-03-17T00:47:51Z',
#      'ordering': 1.0},
#     {'type': '003',
#      'location': '/carpicture04/pic3924/39244068_003.jpg',
#      'updatedDate': '2025-03-17T00:47:51Z',
#      'ordering': 3.0},
#     {'type': '004',
#      'location': '/carpicture04/pic3924/39244068_004.jpg',
#      'updatedDate': '2025-03-17T00:47:51Z',
#      'ordering': 4.0},
#     {'type': '007',
#      'location': '/carpicture04/pic3924/39244068_007.jpg',
#      'updatedDate': '2025-03-17T00:47:51Z',
#      'ordering': 7.0}],
#    'Manufacturer': '현대',
#    'Model': '그랜저 하이브리드 (GN7)',
#    'Badge': '캘리그래피',
#    'GreenType': 'Y',
#    'EvType': '하이브리드',
#    'FuelType': '가솔린+전기',
#    'Year': 202304.0,
#    'FormYear': '2023',
#    'Mileage': 69115.0,
#    'HomeServiceVerification': 'Y',
#    'ServiceCopyCar': 'DUPLICATION',
#    'Price': 3499.0,
#    'SellType': '일반',
#    'BuyType': ['Delivery'],
#    'OfficeCityState': '대전'},
#   {'Id': '39244068',
#    'Separation': ['B'],
#    'Trust': ['Warranty', 'ExtendWarranty'],
#    'ServiceMark': ['EncarDiagnosisP0'],
#    'Condition': ['Inspection', 'Record', 'Resume'],
#    'Photo': '/carpicture04/pic3924/39244068_',
#    'Photos': [{'type': '001',
#      'location': '/carpicture04/pic3924/39244068_001.jpg',
#      'updatedDate': '2025-03-17T00:47:51Z',
#      'ordering': 1.0},
#     {'type': '003',
#      'location': '/carpicture04/pic3924/39244068_003.jpg',
#      'updatedDate': '2025-03-17T00:47:51Z',
#      'ordering': 3.0},
#     {'type': '004',
#      'location': '/carpicture04/pic3924/39244068_004.jpg',
#      'updatedDate': '2025-03-17T00:47:51Z',
#      'ordering': 4.0},
#     {'type': '007',
#      'location': '/carpicture04/pic3924/39244068_007.jpg',
#      'updatedDate': '2025-03-17T00:47:51Z',
#      'ordering': 7.0}],
#    'Manufacturer': '현대',
#    'Model': '그랜저 하이브리드 (GN7)',
#    'Badge': '캘리그래피',
#    'GreenType': 'Y',
#    'EvType': '하이브리드',
#    'FuelType': '가솔린+전기',
#    'Year': 202304.0,
#    'FormYear': '2023',
#    'Mileage': 69115.0,
#    'ServiceCopyCar': 'ORIGINAL',
#    'Price': 3499.0,
#    'SellType': '일반',
#    'BuyType': [],
#    'OfficeCityState': '대전'},
#   {'Id': '39673739',
#    'Separation': ['B'],
#    'Trust': ['Warranty'],
#    'ServiceMark': ['EncarDiagnosisP0'],
#    'Condition': ['Inspection', 'Record', 'Resume'],
#    'Photo': '/carpicture07/pic3967/39673739_',
#    'Photos': [{'type': '001',
#      'location': '/carpicture07/pic3967/39673739_001.jpg',
#      'updatedDate': '2025-05-19T07:40:42Z',
#      'ordering': 1.0},
#     {'type': '003',
#      'location': '/carpicture07/pic3967/39673739_003.jpg',
#      'updatedDate': '2025-05-19T07:40:42Z',
#      'ordering': 3.0},
#     {'type': '004',
#      'location': '/carpicture07/pic3967/39673739_004.jpg',
#      'updatedDate': '2025-05-19T07:40:42Z',
#      'ordering': 4.0},
#     {'type': '007',
#      'location': '/carpicture07/pic3967/39673739_007.jpg',
#      'updatedDate': '2025-05-19T07:40:42Z',
#      'ordering': 7.0}],
#    'Manufacturer': '현대',
#    'Model': '그랜저 IG',
#    'Badge': '3.0 LPi 장애인용',
#    'BadgeDetail': '익스클루시브 스페셜',
#    'GreenType': 'N',
#    'FuelType': 'LPG(일반인 구입)',
#    'Year': 201612.0,
#    'FormYear': '2017',
#    'Mileage': 99952.0,
#    'ServiceCopyCar': 'ORIGINAL',
#    'Price': 2080.0,
#    'SellType': '일반',
#    'BuyType': [],
#    'OfficeCityState': '대구'},
#   {'Id': '39451102',
#    'Separation': ['B'],
#    'Trust': [],
#    'ServiceMark': [],
#    'Condition': ['Inspection', 'Record'],
#    'Photo': '/carpicture05/pic3945/39451102_',
#    'Photos': [{'type': '001',
#      'location': '/carpicture05/pic3945/39451102_001.jpg',
#      'updatedDate': '2025-04-15T03:28:30Z',
#      'ordering': 1.0},
#     {'type': '003',
#      'location': '/carpicture05/pic3945/39451102_003.jpg',
#      'updatedDate': '2025-04-15T03:28:30Z',
#      'ordering': 3.0},
#     {'type': '004',
#      'location': '/carpicture05/pic3945/39451102_004.jpg',
#      'updatedDate': '2025-04-15T03:28:30Z',
#      'ordering': 4.0},
#     {'type': '007',
#      'location': '/carpicture05/pic3945/39451102_007.jpg',
#      'updatedDate': '2025-04-15T03:28:30Z',
#      'ordering': 7.0}],
#    'Manufacturer': '현대',
#    'Model': '그랜저 IG',
#    'Badge': '3.0 익스클루시브',
#    'BadgeDetail': '(세부등급 없음)',
#    'GreenType': 'N',
#    'FuelType': '가솔린',
#    'Year': 201701.0,
#    'FormYear': '2017',
#    'Mileage': 91688.0,
#    'ServiceCopyCar': 'ORIGINAL',
#    'Price': 1800.0,
#    'SellType': '일반',
#    'BuyType': [],
#    'OfficeCityState': '전남'},
#   {'Id': '39975921',
#    'Separation': ['B'],
#    'Trust': [],
#    'ServiceMark': [],
#    'Condition': ['Inspection', 'Record'],
#    'Photo': '/carpicture07/pic3997/39975921_',
#    'Photos': [{'type': '001',
#      'location': '/carpicture07/pic3997/39975921_001.jpg',
#      'updatedDate': '2025-06-30T02:39:12Z',
#      'ordering': 1.0},
#     {'type': '003',
#      'location': '/carpicture07/pic3997/39975921_003.jpg',
#      'updatedDate': '2025-06-30T02:39:12Z',
#      'ordering': 3.0},
#     {'type': '004',
#      'location': '/carpicture07/pic3997/39975921_004.jpg',
#      'updatedDate': '2025-06-30T02:39:12Z',
#      'ordering': 4.0},
#     {'type': '007',
#      'location': '/carpicture07/pic3997/39975921_007.jpg',
#      'updatedDate': '2025-06-30T02:39:12Z',
#      'ordering': 7.0}],
#    'Manufacturer': '현대',
#    'Model': '그랜저 하이브리드 (GN7)',
#    'Badge': '익스클루시브',
#    'GreenType': 'Y',
#    'EvType': '하이브리드',
#    'FuelType': '가솔린+전기',
#    'Year': 202305.0,
#    'FormYear': '2023',
#    'Mileage': 36610.0,
#    'ServiceCopyCar': 'ORIGINAL',
#    'Price': 3950.0,
#    'SellType': '일반',
#    'BuyType': [],
#    'OfficeCityState': '전남'},
#   {'Id': '39892929',
#    'Separation': ['B'],
#    'Trust': [],
#    'ServiceMark': [],
#    'Condition': ['Inspection', 'Record'],
#    'Photo': '/carpicture09/pic3989/39892929_',
#    'Photos': [{'type': '001',
#      'location': '/carpicture09/pic3989/39892929_001.jpg',
#      'updatedDate': '2025-06-18T03:06:42Z',
#      'ordering': 1.0},
#     {'type': '003',
#      'location': '/carpicture09/pic3989/39892929_003.jpg',
#      'updatedDate': '2025-06-18T03:06:42Z',
#      'ordering': 3.0},
#     {'type': '004',
#      'location': '/carpicture09/pic3989/39892929_004.jpg',
#      'updatedDate': '2025-06-18T03:06:42Z',
#      'ordering': 4.0},
#     {'type': '007',
#      'location': '/carpicture09/pic3989/39892929_007.jpg',
#      'updatedDate': '2025-06-18T03:06:42Z',
#      'ordering': 7.0}],
#    'Manufacturer': '현대',
#    'Model': '그랜저 IG',
#    'Badge': '2.4 프리미엄',
#    'BadgeDetail': '(세부등급 없음)',
#    'GreenType': 'N',
#    'FuelType': '가솔린',
#    'Year': 201805.0,
#    'FormYear': '2019',
#    'Mileage': 90309.0,
#    'ServiceCopyCar': 'ORIGINAL',
#    'Price': 1750.0,
#    'SellType': '일반',
#    'BuyType': [],
#    'OfficeCityState': '전남'},
#   {'Id': '40033974',
#    'Separation': ['B'],
#    'Trust': ['ExtendWarranty', 'HomeService', 'Meetgo'],
#    'ServiceMark': ['EncarMeetgo', 'EncarDiagnosisP1'],
#    'Condition': ['Inspection', 'InspectionDirect', 'Record', 'Resume'],
#    'Photo': '/carpicture03/pic4003/40033970_',
#    'Photos': [{'type': '001',
#      'location': '/carpicture03/pic4003/40033970_001.jpg',
#      'updatedDate': '2025-07-07T07:35:59Z',
#      'ordering': 1.0},
#     {'type': '003',
#      'location': '/carpicture03/pic4003/40033970_003.jpg',
#      'updatedDate': '2025-07-07T07:35:59Z',
#      'ordering': 3.0},
#     {'type': '004',
#      'location': '/carpicture03/pic4003/40033970_004.jpg',
#      'updatedDate': '2025-07-07T07:35:59Z',
#      'ordering': 4.0},
#     {'type': '007',
#      'location': '/carpicture03/pic4003/40033970_007.jpg',
#      'updatedDate': '2025-07-07T07:35:59Z',
#      'ordering': 7.0}],
#    'Manufacturer': '현대',
#    'Model': '그랜저 (GN7)',
#    'Badge': '2.5 가솔린 2WD',
#    'BadgeDetail': '프리미엄',
#    'GreenType': 'N',
#    'FuelType': '가솔린',
#    'Year': 202301.0,
#    'FormYear': '2023',
#    'Mileage': 66825.0,
#    'HomeServiceVerification': 'Y',
#    'ServiceCopyCar': 'DUPLICATION',
#    'Price': 7777.0,
#    'SellType': '일반',
#    'BuyType': ['Delivery', 'Visit'],
#    'OfficeCityState': '경기',
#    'IsSingleAd': 'Y'},
#   {'Id': '40416822',
#    'Separation': ['B'],
#    'Trust': ['ExtendWarranty', 'HomeService'],
#    'ServiceMark': ['EncarMeetgo', 'EncarDiagnosisP1'],
#    'Condition': ['Inspection', 'Record', 'Resume'],
#    'Photo': '/carpicture06/pic3996/39961154_',
#    'Photos': [{'type': '001',
#      'location': '/carpicture06/pic3996/39961154_001.jpg',
#      'updatedDate': '2025-06-30T01:41:11Z',
#      'ordering': 1.0},
#     {'type': '003',
#      'location': '/carpicture06/pic3996/39961154_003.jpg',
#      'updatedDate': '2025-06-30T01:41:11Z',
#      'ordering': 3.0},
#     {'type': '004',
#      'location': '/carpicture06/pic3996/39961154_004.jpg',
#      'updatedDate': '2025-06-30T01:41:11Z',
#      'ordering': 4.0},
#     {'type': '007',
#      'location': '/carpicture06/pic3996/39961154_007.jpg',
#      'updatedDate': '2025-06-30T01:41:11Z',
#      'ordering': 7.0}],
#    'Manufacturer': '현대',
#    'Model': '그랜저 IG',
#    'Badge': '3.0 익스클루시브',
#    'BadgeDetail': '(세부등급 없음)',
#    'GreenType': 'N',
#    'FuelType': '가솔린',
#    'Year': 201703.0,
#    'FormYear': '2017',
#    'Mileage': 142458.0,
#    'HomeServiceVerification': 'Y',
#    'ServiceCopyCar': 'DUPLICATION',
#    'Price': 1320.0,
#    'SellType': '일반',
#    'BuyType': ['Delivery'],
#    'OfficeCityState': '인천'},
#   {'Id': '40380787',
#    'Separation': ['B'],
#    'Trust': ['ExtendWarranty', 'HomeService'],
#    'ServiceMark': ['EncarMeetgo', 'EncarDiagnosisP1'],
#    'Condition': ['Inspection', 'Record', 'Resume'],
#    'Photo': '/carpicture08/pic4038/40380640_',
#    'Photos': [{'type': '001',
#      'location': '/carpicture08/pic4038/40380640_001.jpg',
#      'updatedDate': '2025-08-26T03:22:10Z',
#      'ordering': 1.0},
#     {'type': '003',
#      'location': '/carpicture08/pic4038/40380640_003.jpg',
#      'updatedDate': '2025-08-26T03:22:10Z',
#      'ordering': 3.0},
#     {'type': '004',
#      'location': '/carpicture08/pic4038/40380640_004.jpg',
#      'updatedDate': '2025-08-26T03:22:10Z',
#      'ordering': 4.0},
#     {'type': '007',
#      'location': '/carpicture08/pic4038/40380640_007.jpg',
#      'updatedDate': '2025-08-26T03:22:10Z',
#      'ordering': 7.0}],
#    'Manufacturer': '현대',
#    'Model': '더 뉴 그랜저 IG',
#    'Badge': '2.5',
#    'BadgeDetail': '프리미엄',
#    'GreenType': 'N',
#    'FuelType': '가솔린',
#    'Year': 202107.0,
#    'FormYear': '2022',
#    'Mileage': 89391.0,
#    'HomeServiceVerification': 'Y',
#    'ServiceCopyCar': 'DUPLICATION',
#    'Price': 2190.0,
#    'SellType': '일반',
#    'BuyType': ['Delivery'],
#    'OfficeCityState': '서울'},
#   {'Id': '40403855',
#    'Separation': ['B'],
#    'Trust': ['ExtendWarranty', 'HomeService'],
#    'ServiceMark': ['EncarMeetgo', 'EncarDiagnosisP1'],
#    'Condition': ['Inspection', 'Record', 'Resume'],
#    'Photo': '/carpicture08/pic4038/40386422_',
#    'Photos': [{'type': '001',
#      'location': '/carpicture08/pic4038/40386422_001.jpg',
#      'updatedDate': '2025-08-28T06:54:23Z',
#      'ordering': 1.0},
#     {'type': '003',
#      'location': '/carpicture08/pic4038/40386422_003.jpg',
#      'updatedDate': '2025-08-28T06:54:23Z',
#      'ordering': 3.0},
#     {'type': '004',
#      'location': '/carpicture08/pic4038/40386422_004.jpg',
#      'updatedDate': '2025-08-28T06:54:23Z',
#      'ordering': 4.0},
#     {'type': '007',
#      'location': '/carpicture08/pic4038/40386422_007.jpg',
#      'updatedDate': '2025-08-28T06:54:23Z',
#      'ordering': 7.0}],
#    'Manufacturer': '현대',
#    'Model': '그랜저 HG',
#    'Badge': 'HG240 모던',
#    'GreenType': 'N',
#    'FuelType': '가솔린',
#    'Year': 201512.0,
#    'FormYear': '2016',
#    'Mileage': 129423.0,
#    'HomeServiceVerification': 'Y',
#    'ServiceCopyCar': 'DUPLICATION',
#    'Price': 820.0,
#    'SellType': '일반',
#    'BuyType': ['Delivery'],
#    'OfficeCityState': '인천'},
#   {'Id': '39896983',
#    'Separation': ['B'],
#    'Trust': ['ExtendWarranty', 'HomeService'],
#    'ServiceMark': ['EncarMeetgo', 'EncarDiagnosisP1'],
#    'Condition': ['Inspection', 'Record', 'Resume'],
#    'Photo': '/carpicture07/pic3987/39878182_',
#    'Photos': [{'type': '001',
#      'location': '/carpicture07/pic3987/39878182_001.jpg',
#      'updatedDate': '2025-06-18T07:52:23Z',
#      'ordering': 1.0},
#     {'type': '003',
#      'location': '/carpicture07/pic3987/39878182_003.jpg',
#      'updatedDate': '2025-06-18T07:52:23Z',
#      'ordering': 3.0},
#     {'type': '004',
#      'location': '/carpicture07/pic3987/39878182_004.jpg',
#      'updatedDate': '2025-06-18T07:52:23Z',
#      'ordering': 4.0},
#     {'type': '007',
#      'location': '/carpicture07/pic3987/39878182_007.jpg',
#      'updatedDate': '2025-06-18T07:52:23Z',
#      'ordering': 7.0}],
#    'Manufacturer': '현대',
#    'Model': '그랜저 IG 하이브리드',
#    'Badge': '익스클루시브',
#    'BadgeDetail': '스페셜',
#    'GreenType': 'Y',
#    'EvType': '하이브리드',
#    'FuelType': '가솔린+전기',
#    'Year': 201910.0,
#    'FormYear': '2019',
#    'Mileage': 76041.0,
#    'HomeServiceVerification': 'Y',
#    'ServiceCopyCar': 'DUPLICATION',
#    'Price': 2390.0,
#    'SellType': '일반',
#    'BuyType': ['Delivery'],
#    'OfficeCityState': '인천'}]}

# %%
CarSeq = '40176071'

response = requests.get(f'https://api.encar.com/v1/readside/vehicle/{CarSeq}?include=CATEGORY,SPEC,OPTIONS,PHOTOS,CONDITION,CONTENTS,VIN,MANAGE', headers=headers)

response.status_code
# Out:
# 404

# %%
CarSeq = '40377623'

response = requests.get(f"https://api.encar.com/v1/readside/inspection/vehicle/{CarSeq}", headers=headers)

response.status_code
# Out:
# 404

# %%
CarSeq = '40377623'

#차량 보험 이력 및 차량 정보 리포트 (차량 모델,최초 등록일, 연료/배기량 , 내차피해,타차피해,전손/침수이력력, 소유자변경,차량변경, 용도 이력, 저당 정보)
response = requests.get(f"https://api.encar.com/v1/readside/record/vehicle/{CarSeq}/open", headers=headers)

response.status_code
# Out:
# 404

# %%
response.json()
# Out:
# {'manage': {'dummy': False,
#   'dummyVehicleId': None,
#   'reRegistered': False,
#   'webReserved': True,
#   'registDateTime': '2025-08-26T08:27:30',
#   'firstAdvertisedDateTime': '2025-08-27T09:43:00',
#   'modifyDateTime': '2025-09-25T16:43:02',
#   'subscribeCount': 3,
#   'viewCount': 674},
#  'category': {'type': 'CAR',
#   'manufacturerCd': '001',
#   'manufacturerName': '현대',
#   'modelCd': '125',
#   'modelName': '그랜저 HG 하이브리드',
#   'gradeCd': '001',
#   'gradeName': '프리미엄',
#   'gradeEnglishName': 'Premium',
#   'yearMonth': '201412',
#   'formYear': '2015',
#   'domestic': True,
#   'importType': 'NONE_IMPORT_TYPE',
#   'originPrice': 3603,
#   'manufacturerEnglishName': 'Hyundai',
#   'modelGroupCd': '004',
#   'modelGroupName': '그랜저',
#   'modelGroupEnglishName': 'Grandeur',
#   'gradeDetailCd': None,
#   'gradeDetailName': None,
#   'gradeDetailEnglishName': None,
#   'jatoVehicleId': 726188120140101,
#   'warranty': {'userDefined': False,
#    'companyName': None,
#    'bodyMonth': 36,
#    'bodyMileage': 60000,
#    'transmissionMonth': 60,
#    'transmissionMileage': 100000}},
#  'advertisement': None,
#  'contact': None,
#  'spec': {'type': 'CAR',
#   'mileage': 144009,
#   'displacement': 2359,
#   'transmissionName': '오토',
#   'fuelCd': '006',
#   'fuelName': '가솔린+전기',
#   'colorName': '검정색',
#   'customColor': None,
#   'seatCount': 5,
#   'bodyName': '대형차'},
#  'photos': [{'code': '010',
#    'path': '/carpicture07/pic4037/40377623_010.jpg',
#    'type': 'INNER',
#    'updateDateTime': '2025-08-27T11:57:03',
#    'desc': None},
#   {'code': '007',
#    'path': '/carpicture07/pic4037/40377623_007.jpg',
#    'type': 'INNER',
#    'updateDateTime': '2025-08-27T11:57:03',
#    'desc': None},
#   {'code': '011',
#    'path': '/carpicture07/pic4037/40377623_001.jpg',
#    'type': 'THUMBNAIL',
#    'updateDateTime': '2025-08-27T11:57:03',
#    'desc': None},
#   {'code': '012',
#    'path': '/carpicture07/pic4037/40377623_001.jpg',
#    'type': 'THUMBNAIL',
#    'updateDateTime': '2025-08-27T11:57:03',
#    'desc': None},
#   {'code': '018',
#    'path': '/carpicture07/pic4037/40377623_018.jpg',
#    'type': 'OPTION',
#    'updateDateTime': '2025-08-27T11:57:03',
#    'desc': None},
#   {'code': '003',
#    'path': '/carpicture07/pic4037/40377623_003.jpg',
#    'type': 'OUTER',
#    'updateDateTime': '2025-08-27T11:57:03',
#    'desc': '전국최저가! 하부누유X(리프트확인가능).모든옵션 정상작동.'},
#   {'code': '016',
#    'path': '/carpicture07/pic4037/40377623_016.jpg',
#    'type': 'OPTION',
#    'updateDateTime': '2025-08-27T11:57:03',
#    'desc': None},
#   {'code': '009',
#    'path': '/carpicture07/pic4037/40377623_009.jpg',
#    'type': 'INNER',
#    'updateDateTime': '2025-08-27T11:57:03',
#    'desc': None},
#   {'code': '020',
#    'path': '/carpicture07/pic4037/40377623_020.jpg',
#    'type': 'OPTION',
#    'updateDateTime': '2025-08-27T11:57:03',
#    'desc': None},
#   {'code': '008',
#    'path': '/carpicture07/pic4037/40377623_008.jpg',
#    'type': 'INNER',
#    'updateDateTime': '2025-08-27T11:57:03',
#    'desc': None},
#   {'code': '021',
#    'path': '/carpicture07/pic4037/40377623_021.jpg',
#    'type': 'OPTION',
#    'updateDateTime': '2025-08-27T11:57:03',
#    'desc': None},
#   {'code': '023',
#    'path': '/carpicture07/pic4037/40377623_023.jpg',
#    'type': 'OPTION',
#    'updateDateTime': '2025-08-27T11:57:03',
#    'desc': None},
#   {'code': '006',
#    'path': '/carpicture07/pic4037/40377623_006.jpg',
#    'type': 'INNER',
#    'updateDateTime': '2025-08-27T11:57:03',
#    'desc': None},
#   {'code': '005',
#    'path': '/carpicture07/pic4037/40377623_005.jpg',
#    'type': 'OUTER',
#    'updateDateTime': '2025-08-27T11:57:03',
#    'desc': '전국최저가! 하부누유X(리프트확인가능).모든옵션 정상작동.'},
#   {'code': '019',
#    'path': '/carpicture07/pic4037/40377623_019.jpg',
#    'type': 'OPTION',
#    'updateDateTime': '2025-08-27T11:57:03',
#    'desc': None},
#   {'code': '026',
#    'path': '/carpicture07/pic4037/40377623_001.jpg',
#    'type': 'THUMBNAIL',
#    'updateDateTime': '2025-08-27T11:57:03',
#    'desc': None},
#   {'code': '025',
#    'path': '/carpicture07/pic4037/40377623_001.jpg',
#    'type': 'THUMBNAIL',
#    'updateDateTime': '2025-08-27T11:57:03',
#    'desc': None},
#   {'code': '014',
#    'path': '/carpicture07/pic4037/40377623_007.jpg',
#    'type': 'THUMBNAIL',
#    'updateDateTime': '2025-08-27T11:57:03',
#    'desc': None},
#   {'code': '024',
#    'path': '/carpicture07/pic4037/40377623_024.jpg',
#    'type': 'OPTION',
#    'updateDateTime': '2025-08-27T11:57:03',
#    'desc': None},
#   {'code': '002',
#    'path': '/carpicture07/pic4037/40377623_002.jpg',
#    'type': 'OUTER',
#    'updateDateTime': '2025-08-27T11:57:03',
#    'desc': '전국최저가! 하부누유X(리프트확인가능).모든옵션 정상작동.'},
#   {'code': '015',
#    'path': '/carpicture07/pic4037/40377623_015.jpg',
#    'type': 'OPTION',
#    'updateDateTime': '2025-08-27T11:57:03',
#    'desc': None},
#   {'code': '022',
#    'path': '/carpicture07/pic4037/40377623_022.jpg',
#    'type': 'OPTION',
#    'updateDateTime': '2025-08-27T11:57:03',
#    'desc': None},
#   {'code': '013',
#    'path': '/carpicture07/pic4037/40377623_001.jpg',
#    'type': 'THUMBNAIL',
#    'updateDateTime': '2025-08-27T11:57:03',
#    'desc': None},
#   {'code': '017',
#    'path': '/carpicture07/pic4037/40377623_017.jpg',
#    'type': 'OPTION',
#    'updateDateTime': '2025-08-27T11:57:03',
#    'desc': None},
#   {'code': '001',
#    'path': '/carpicture07/pic4037/40377623_001.jpg',
#    'type': 'OUTER',
#    'updateDateTime': '2025-08-27T11:57:03',
#    'desc': '전국최저가! 하부누유X(리프트확인가능).모든옵션 정상작동.'},
#   {'code': '004',
#    'path': '/carpicture07/pic4037/40377623_004.jpg',
#    'type': 'OUTER',
#    'updateDateTime': '2025-08-27T11:57:03',
#    'desc': '전국최저가! 하부누유X(리프트확인가능).모든옵션 정상작동.'}],
#  'options': {'type': 'CAR',
#   'standard': ['001',
#    '003',
#    '004',
#    '005',
#    '006',
#    '007',
#    '008',
#    '014',
#    '015',
#    '017',
#    '019',
#    '020',
#    '021',
#    '022',
#    '023',
#    '024',
#    '026',
#    '027',
#    '030',
#    '031',
#    '032',
#    '033',
#    '035',
#    '055',
#    '056',
#    '057',
#    '058',
#    '063',
#    '068',
#    '071',
#    '072',
#    '074',
#    '082',
#    '085',
#    '094',
#    '096',
#    '097'],
#   'etc': [],
#   'choice': [],
#   'tuning': []},
#  'condition': {'accident': {'recordView': False, 'resumeView': True},
#   'inspection': {'formats': []},
#   'seizing': {'seizingCount': 0, 'pledgeCount': 0}},
#  'partnership': None,
#  'contents': {'text': '『안녕하세요』중고차 판매 전문딜러 프로모터스 “이병희”입니다\n\n 엔카광고 판매대수 연간 “180대이상” 직접 매입&직접 판매합니다.\n\n▣▣▣▣▣▣▣▣▣▣▣▣▣▣▣▣▣▣▣▣▣▣▣▣▣▣\n\n▣ 판매자의 한마디\n\n\n                         ★침수차량.전손차량.키로수이상(원부.갑부등 전부 확인합니다) 있는 차량들은  일체 취급하지 않습니다!! (계약서명시)★\n\n\n★ 엔진.밋션.및 하부상태 확실하게 체크하였습니다 \n\n★ 모든옵션 정상유뮤  체크하였습니다\n\n★ 실내및 외관상태 너무 깨끗하게 관리 하셨습니다 \n\n★ 하부.부식.누유 없습니다(오시면 리프트 확인가능)\n\n★ 주유만하시고 운행하셔도 될정도로  차량 컨디션 아주 좋습니다 \n\n ★삼성화재(손해보험) ◀ 가입완료한 차량이며 확실한 \n\n    성능업체 1, 2차 성능완료 하였습니다 ★\n\n\n\n\n▶  차량 + 등록비 + 보험료까지 전액할부 및 추가할부가능.\n\n ▶  연  식 :  2014년 12월\n\n ▶  차량명:  그랜져HG 하이브리드 \n\n ▶  사고유무 : 본넷.트렁크쪽교환\n\n ▶  주행거리 144.008km\n\n ━━☆━━━━━━☆━━━━━━☆━━━━━━☆━━━━━━☆\n\n   출발 전 사전 예약을 주시면, 시승과 점검이 가능하도록 차량을 \n\n   준비합니다.  3가지 생각만 버리고 오시면됩니다 \n\n  (허위매물, 침수유무 조작,키로수조작)\n\n  제가 판매하는 차량에는 해당사항이 없음을 당당하게 밝힙니다.\n\n▧▧▧▧▧▧▧▧▧▧▧▧▧▧▧▧▧▧▧▧▧\n\n  (신주소) 대구 북구 노원로 115  오토월드\n\n    4층 403호 프로모터스 오시면됩니다\n\n ▧▧▧▧▧▧▧▧▧▧▧▧▧▧▧▧▧▧▧▧▧\n\n 버스 이용시 한국로봇산업진흥원앞 정류소 하차후\n\n 오토월드입구 오셔서 엘리베이터를 이용 4층 403호\n\n 프로모터스 사무실로 오시면됩니다.\n\n 북구1, 서구1-1, 칠곡2 , 순환3-1(한국로봇산업진흥원앞)',
#   'meetGoText': None},
#  'view': None,
#  'vehicleType': 'CAR',
#  'vehicleId': 40377623,
#  'vehicleNo': '110구7086',
#  'vin': 'KMHFG413BFA012859'}

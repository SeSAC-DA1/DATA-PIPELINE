# %%
import os, re, time, json
import pandas as pd
import requests
from requests.adapters import HTTPAdapter, Retry
from concurrent.futures import ThreadPoolExecutor, as_completed
from typing import List, Dict, Any, Optional


headers = {
    "accept": "application/json, text/javascript, */*; q=0.01",
    "accept-encoding": "gzip, deflate, br, zstd",
    "accept-language": "ko,ko-KR;q=0.9,en-US;q=0.8,en;q=0.7",
    "origin": "https://www.encar.com",
    "referer": "https://www.encar.com/",
    "sec-ch-ua": '"Chromium";v="140", "Not=A?Brand";v="24", "Google Chrome";v="140"',
    "sec-ch-ua-mobile": "?0",
    "sec-ch-ua-platform": '"Windows"',
    "sec-fetch-dest": "empty",
    "sec-fetch-mode": "cors",
    "sec-fetch-site": "same-site",
    "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/140.0.0.0 Safari/537.36"
}

res = requests.get('https://api.encar.com/search/car/list/general?count=true&q=(And.Hidden.N._.(C.CarType.Y._.(C.Manufacturer.%ED%98%84%EB%8C%80._.ModelGroup.%EA%B7%B8%EB%9E%9C%EC%A0%80.)))&sr=%7CModifiedDate%7C0%7C8', headers=headers)

https://api.encar.com/search/car/list/general?count=true&q=(And.Hidden.N._.(C.CarType.Y._.(C.Manufacturer.%ED%98%84%EB%8C%80._.ModelGroup.%EA%B7%B8%EB%9E%9C%EC%A0%80.)))&inav=%7CMetadata%7CSort

res.status_code
# Out:
# 200

# %%
res.json()
# Out:
# {'Count': 9671,
#  'SearchResults': [{'Id': '40623881',
#    'Separation': ['B'],
#    'Trust': ['HomeService'],
#    'ServiceMark': ['EncarMeetgo', 'EncarDiagnosisP0'],
#    'Condition': ['Record', 'Resume'],
#    'Photo': '/carpicture10/pic4060/40607179_',
#    'Photos': [{'type': '001',
#      'location': '/carpicture10/pic4060/40607179_001.jpg',
#      'updatedDate': '2025-09-25T06:02:27Z',
#      'ordering': 1.0},
#     {'type': '003',
#      'location': '/carpicture10/pic4060/40607179_003.jpg',
#      'updatedDate': '2025-09-25T06:02:27Z',
#      'ordering': 3.0},
#     {'type': '004',
#      'location': '/carpicture10/pic4060/40607179_004.jpg',
#      'updatedDate': '2025-09-25T06:02:27Z',
#      'ordering': 4.0},
#     {'type': '007',
#      'location': '/carpicture10/pic4060/40607179_007.jpg',
#      'updatedDate': '2025-09-25T06:02:27Z',
#      'ordering': 7.0}],
#    'Manufacturer': '현대',
#    'Model': '그랜저 HG',
#    'Badge': 'HG220 디젤 프리미엄',
#    'GreenType': 'N',
# ...

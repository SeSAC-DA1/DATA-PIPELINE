# %%
import os, re, time, json
import pandas as pd
import requests
from requests.adapters import HTTPAdapter, Retry
from concurrent.futures import ThreadPoolExecutor, as_completed
from typing import List, Dict, Any, Optional


headers = {
    "accept": "application/json, text/javascript, */*; q=0.01",
    "accept-encoding": "gzip, deflate, br, zstd",
    "accept-language": "ko,ko-KR;q=0.9,en-US;q=0.8,en;q=0.7",
    "origin": "https://www.encar.com",
    "referer": "https://www.encar.com/",
    "sec-ch-ua": '"Chromium";v="140", "Not=A?Brand";v="24", "Google Chrome";v="140"',
    "sec-ch-ua-mobile": "?0",
    "sec-ch-ua-platform": '"Windows"',
    "sec-fetch-dest": "empty",
    "sec-fetch-mode": "cors",
    "sec-fetch-site": "same-site",
    "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/140.0.0.0 Safari/537.36"
}
#전체 차량 카운트 api
res = requests.get('https://api.encar.com/search/car/list/general?count=true&q=(And.Hidden.N._.CarType.N.)&inav=%7CMetadata%7CSort', headers=headers)


res.status_code
# Out:
# 200

# %%
page = 0            # 0,1,2,...
page_size = 20
start = page * page_size
url = "https://api.encar.com/search/car/list/general"

params = {
    # 일반광고 필터(AdType.A) 제거 → 전체 매물
    "q": "(And.Hidden.N._.(C.CarType.Y._.(C.Manufacturer.현대._.ModelGroup.그랜저.)))",
    "sr": f"|ModifiedDate|{start}|{page_size}",
}


# 현대 그랜저 차량 목록(전체 매물)
res = requests.get(url, headers=headers,params=params)

res.status_code
# Out:
# 200

# %%
res.json()
# Out:
# {'SearchResults': [{'Id': '40394824',
#    'Separation': ['B'],
#    'Trust': ['ExtendWarranty', 'HomeService'],
#    'ServiceMark': ['EncarMeetgo', 'EncarDiagnosisP1'],
#    'Condition': ['Inspection', 'Record', 'Resume'],
#    'Photo': '/carpicture09/pic4039/40393565_',
#    'Photos': [{'type': '001',
#      'location': '/carpicture09/pic4039/40393565_001.jpg',
#      'updatedDate': '2025-08-27T07:59:53Z',
#      'ordering': 1.0},
#     {'type': '003',
#      'location': '/carpicture09/pic4039/40393565_003.jpg',
#      'updatedDate': '2025-08-27T07:59:53Z',
#      'ordering': 3.0},
#     {'type': '004',
#      'location': '/carpicture09/pic4039/40393565_004.jpg',
#      'updatedDate': '2025-08-27T07:59:53Z',
#      'ordering': 4.0},
#     {'type': '007',
#      'location': '/carpicture09/pic4039/40393565_007.jpg',
#      'updatedDate': '2025-08-27T07:59:53Z',
#      'ordering': 7.0}],
#    'Manufacturer': '현대',
#    'Model': '더 뉴 그랜저 IG',
#    'Badge': '2.5',
#    'BadgeDetail': '르블랑',
#    'GreenType': 'N',
#    'FuelType': '가솔린',
#    'Year': 202207.0,
#    'FormYear': '2023',
#    'Mileage': 95044.0,
#    'HomeServiceVerification': 'Y',
#    'ServiceCopyCar': 'DUPLICATION',
#    'Price': 2200.0,
#    'SellType': '일반',
#    'BuyType': ['Delivery'],
#    'OfficeCityState': '대전'},
#   {'Id': '40448742',
#    'Separation': ['B'],
#    'Trust': ['HomeService'],
#    'ServiceMark': ['EncarMeetgo', 'EncarDiagnosisP1'],
#    'Condition': ['Inspection', 'Record', 'Resume'],
#    'Photo': '/carpicture04/pic4044/40442677_',
#    'Photos': [{'type': '001',
#      'location': '/carpicture04/pic4044/40442677_001.jpg',
#      'updatedDate': '2025-09-03T07:16:24Z',
#      'ordering': 1.0},
#     {'type': '003',
#      'location': '/carpicture04/pic4044/40442677_003.jpg',
#      'updatedDate': '2025-09-03T07:16:24Z',
#      'ordering': 3.0},
#     {'type': '004',
#      'location': '/carpicture04/pic4044/40442677_004.jpg',
#      'updatedDate': '2025-09-03T07:16:24Z',
#      'ordering': 4.0},
#     {'type': '007',
#      'location': '/carpicture04/pic4044/40442677_007.jpg',
#      'updatedDate': '2025-09-03T07:16:24Z',
#      'ordering': 7.0}],
#    'Manufacturer': '현대',
#    'Model': '그랜저 HG',
#    'Badge': 'HG300 익스클루시브',
#    'GreenType': 'N',
#    'FuelType': '가솔린',
#    'Year': 201404.0,
#    'FormYear': '2014',
#    'Mileage': 139202.0,
#    'HomeServiceVerification': 'Y',
#    'ServiceCopyCar': 'DUPLICATION',
#    'Price': 730.0,
#    'SellType': '일반',
#    'BuyType': ['Delivery'],
#    'OfficeCityState': '경기'},
#   {'Id': '40315033',
#    'Separation': ['B'],
#    'Trust': ['ExtendWarranty', 'HomeService'],
#    'ServiceMark': ['EncarMeetgo', 'EncarDiagnosisP1'],
#    'Condition': ['Inspection', 'Record', 'Resume'],
#    'Photo': '/carpicture01/pic4031/40313261_',
#    'Photos': [{'type': '001',
#      'location': '/carpicture01/pic4031/40313261_001.jpg',
#      'updatedDate': '2025-08-18T00:27:48Z',
#      'ordering': 1.0},
#     {'type': '003',
#      'location': '/carpicture01/pic4031/40313261_003.jpg',
#      'updatedDate': '2025-08-18T00:27:48Z',
#      'ordering': 3.0},
#     {'type': '004',
#      'location': '/carpicture01/pic4031/40313261_004.jpg',
#      'updatedDate': '2025-08-18T00:27:48Z',
#      'ordering': 4.0},
#     {'type': '007',
#      'location': '/carpicture01/pic4031/40313261_007.jpg',
#      'updatedDate': '2025-08-18T00:27:48Z',
#      'ordering': 7.0}],
#    'Manufacturer': '현대',
#    'Model': '그랜저 IG',
#    'Badge': '3.0 익스클루시브',
#    'BadgeDetail': '(세부등급 없음)',
#    'GreenType': 'N',
#    'FuelType': '가솔린',
#    'Year': 201807.0,
#    'FormYear': '2018',
#    'Mileage': 125244.0,
#    'HomeServiceVerification': 'Y',
#    'ServiceCopyCar': 'DUPLICATION',
#    'Price': 1480.0,
#    'SellType': '일반',
#    'BuyType': ['Delivery'],
#    'OfficeCityState': '경기'},
#   {'Id': '40611870',
#    'Separation': ['B'],
#    'Trust': ['HomeService'],
#    'ServiceMark': ['EncarMeetgo', 'EncarDiagnosisP1'],
#    'Condition': ['Inspection', 'Record', 'Resume'],
#    'Photo': '/carpicture09/pic4059/40595256_',
#    'Photos': [{'type': '001',
#      'location': '/carpicture09/pic4059/40595256_001.jpg',
#      'updatedDate': '2025-09-24T04:54:32Z',
#      'ordering': 1.0},
#     {'type': '003',
#      'location': '/carpicture09/pic4059/40595256_003.jpg',
#      'updatedDate': '2025-09-24T04:54:32Z',
#      'ordering': 3.0},
#     {'type': '004',
#      'location': '/carpicture09/pic4059/40595256_004.jpg',
#      'updatedDate': '2025-09-24T04:54:32Z',
#      'ordering': 4.0},
#     {'type': '007',
#      'location': '/carpicture09/pic4059/40595256_007.jpg',
#      'updatedDate': '2025-09-24T04:54:32Z',
#      'ordering': 7.0}],
#    'Manufacturer': '현대',
#    'Model': '그랜저 (GN7)',
#    'Badge': '3.5 LPG 2WD (택시형)',
#    'BadgeDetail': '고급형',
#    'GreenType': 'N',
#    'FuelType': 'LPG(일반인 구입)',
#    'Year': 202503.0,
#    'FormYear': '2025',
#    'Mileage': 33954.0,
#    'HomeServiceVerification': 'Y',
#    'ServiceCopyCar': 'DUPLICATION',
#    'Price': 3090.0,
#    'SellType': '일반',
#    'BuyType': ['Delivery'],
#    'OfficeCityState': '울산'},
#   {'Id': '40247916',
#    'Separation': ['B'],
#    'Trust': ['ExtendWarranty', 'HomeService'],
#    'ServiceMark': ['EncarMeetgo', 'EncarDiagnosisP1'],
#    'Condition': ['Inspection', 'Record', 'Resume'],
#    'Photo': '/carpicture03/pic4023/40236833_',
#    'Photos': [{'type': '001',
#      'location': '/carpicture03/pic4023/40236833_001.jpg',
#      'updatedDate': '2025-08-06T05:43:02Z',
#      'ordering': 1.0},
#     {'type': '003',
#      'location': '/carpicture03/pic4023/40236833_003.jpg',
#      'updatedDate': '2025-08-06T05:43:02Z',
#      'ordering': 3.0},
#     {'type': '004',
#      'location': '/carpicture03/pic4023/40236833_004.jpg',
#      'updatedDate': '2025-08-06T05:43:02Z',
#      'ordering': 4.0},
#     {'type': '007',
#      'location': '/carpicture03/pic4023/40236833_007.jpg',
#      'updatedDate': '2025-08-06T05:43:02Z',
#      'ordering': 7.0}],
#    'Manufacturer': '현대',
#    'Model': '더 뉴 그랜저 IG 하이브리드',
#    'Badge': '캘리그래피',
#    'GreenType': 'Y',
#    'EvType': '하이브리드',
#    'FuelType': '가솔린+전기',
#    'Year': 202008.0,
#    'FormYear': '2020',
#    'Mileage': 72009.0,
#    'HomeServiceVerification': 'Y',
#    'ServiceCopyCar': 'DUPLICATION',
#    'Price': 2930.0,
#    'SellType': '일반',
#    'BuyType': ['Delivery'],
#    'OfficeCityState': '대구'},
#   {'Id': '40551146',
#    'Separation': ['B'],
#    'Trust': ['ExtendWarranty', 'HomeService'],
#    'ServiceMark': ['EncarMeetgo', 'EncarDiagnosisP1'],
#    'Condition': ['Inspection', 'Record', 'Resume'],
#    'Photo': '/carpicture03/pic4053/40537501_',
#    'Photos': [{'type': '001',
#      'location': '/carpicture03/pic4053/40537501_001.jpg',
#      'updatedDate': '2025-09-16T09:43:29Z',
#      'ordering': 1.0},
#     {'type': '003',
#      'location': '/carpicture03/pic4053/40537501_003.jpg',
#      'updatedDate': '2025-09-16T09:43:29Z',
#      'ordering': 3.0},
#     {'type': '004',
#      'location': '/carpicture03/pic4053/40537501_004.jpg',
#      'updatedDate': '2025-09-16T09:43:29Z',
#      'ordering': 4.0},
#     {'type': '007',
#      'location': '/carpicture03/pic4053/40537501_007.jpg',
#      'updatedDate': '2025-09-16T09:43:29Z',
#      'ordering': 7.0}],
#    'Manufacturer': '현대',
#    'Model': '더 뉴 그랜저 IG',
#    'Badge': '2.5',
#    'BadgeDetail': '르블랑',
#    'GreenType': 'N',
#    'FuelType': '가솔린',
#    'Year': 202111.0,
#    'FormYear': '2022',
#    'Mileage': 83425.0,
#    'HomeServiceVerification': 'Y',
#    'ServiceCopyCar': 'DUPLICATION',
#    'Price': 2630.0,
#    'SellType': '일반',
#    'BuyType': ['Delivery'],
#    'OfficeCityState': '경기'},
#   {'Id': '40533575',
#    'Separation': ['B'],
#    'Trust': ['ExtendWarranty', 'HomeService', 'Meetgo'],
#    'ServiceMark': ['EncarMeetgo', 'EncarDiagnosisP2'],
#    'Condition': ['Inspection', 'InspectionDirect', 'Record', 'Resume'],
#    'Photo': '/carpicture03/pic4053/40533566_',
#    'Photos': [{'type': '001',
#      'location': '/carpicture03/pic4053/40533566_027.jpg',
#      'updatedDate': '2025-09-16T00:43:22Z',
#      'ordering': 1.0},
#     {'type': '003',
#      'location': '/carpicture03/pic4053/40533566_003.jpg',
#      'updatedDate': '2025-09-16T00:43:22Z',
#      'ordering': 3.0},
#     {'type': '004',
#      'location': '/carpicture03/pic4053/40533566_004.jpg',
#      'updatedDate': '2025-09-16T00:43:22Z',
#      'ordering': 4.0},
#     {'type': '007',
#      'location': '/carpicture03/pic4053/40533566_007.jpg',
#      'updatedDate': '2025-09-16T00:43:22Z',
#      'ordering': 7.0}],
#    'Manufacturer': '현대',
#    'Model': '더 뉴 그랜저 IG',
#    'Badge': '2.5',
#    'BadgeDetail': '르블랑',
#    'GreenType': 'N',
#    'FuelType': '가솔린',
#    'Year': 202202.0,
#    'FormYear': '2022',
#    'Mileage': 65545.0,
#    'HomeServiceVerification': 'Y',
#    'ServiceCopyCar': 'DUPLICATION',
#    'Price': 2900.0,
#    'SellType': '일반',
#    'BuyType': ['Delivery', 'Visit'],
#    'OfficeCityState': '서울'},
#   {'Id': '40469373',
#    'Separation': ['B'],
#    'Trust': ['ExtendWarranty', 'HomeService'],
#    'ServiceMark': ['EncarMeetgo', 'EncarDiagnosisP1'],
#    'Condition': ['Inspection', 'Record', 'Resume'],
#    'Photo': '/carpicture05/pic4045/40459123_',
#    'Photos': [{'type': '001',
#      'location': '/carpicture05/pic4045/40459123_001.jpg',
#      'updatedDate': '2025-09-05T06:51:46Z',
#      'ordering': 1.0},
#     {'type': '003',
#      'location': '/carpicture05/pic4045/40459123_003.jpg',
#      'updatedDate': '2025-09-05T06:51:46Z',
#      'ordering': 3.0},
#     {'type': '004',
#      'location': '/carpicture05/pic4045/40459123_004.jpg',
#      'updatedDate': '2025-09-05T06:51:46Z',
#      'ordering': 4.0},
#     {'type': '007',
#      'location': '/carpicture05/pic4045/40459123_007.jpg',
#      'updatedDate': '2025-09-05T06:51:46Z',
#      'ordering': 7.0}],
#    'Manufacturer': '현대',
#    'Model': '더 뉴 그랜저 IG',
#    'Badge': '3.3',
#    'BadgeDetail': '익스클루시브',
#    'GreenType': 'N',
#    'FuelType': '가솔린',
#    'Year': 202008.0,
#    'FormYear': '2020',
#    'Mileage': 74866.0,
#    'HomeServiceVerification': 'Y',
#    'ServiceCopyCar': 'DUPLICATION',
#    'Price': 2360.0,
#    'SellType': '일반',
#    'BuyType': ['Delivery'],
#    'OfficeCityState': '부산'},
#   {'Id': '40533170',
#    'Separation': ['B'],
#    'Trust': ['Meetgo'],
#    'ServiceMark': ['EncarMeetgo', 'EncarDiagnosisP2'],
#    'Condition': ['Inspection', 'InspectionDirect', 'Record', 'Resume'],
#    'Photo': '/carpicture03/pic4053/40533165_',
#    'Photos': [{'type': '001',
#      'location': '/carpicture03/pic4053/40533165_027.jpg',
#      'updatedDate': '2025-09-16T02:01:35Z',
#      'ordering': 1.0},
#     {'type': '003',
#      'location': '/carpicture03/pic4053/40533165_003.jpg',
#      'updatedDate': '2025-09-16T02:01:35Z',
#      'ordering': 3.0},
#     {'type': '004',
#      'location': '/carpicture03/pic4053/40533165_004.jpg',
#      'updatedDate': '2025-09-16T02:01:35Z',
#      'ordering': 4.0},
#     {'type': '007',
#      'location': '/carpicture03/pic4053/40533165_007.jpg',
#      'updatedDate': '2025-09-16T02:01:35Z',
#      'ordering': 7.0}],
#    'Manufacturer': '현대',
#    'Model': '더 뉴 그랜저 IG',
#    'Badge': '3.3',
#    'BadgeDetail': '캘리그래피',
#    'GreenType': 'N',
#    'FuelType': '가솔린',
#    'Year': 202109.0,
#    'FormYear': '2022',
#    'Mileage': 49375.0,
#    'HomeServiceProgress': 'COMPLETE_CONSIGNMENT',
#    'HomeServiceVerification': 'Y',
#    'ServiceCopyCar': 'DUPLICATION',
#    'Price': 3099.0,
#    'SellType': '일반',
#    'BuyType': ['Visit'],
#    'OfficeCityState': '서울'},
#   {'Id': '39896983',
#    'Separation': ['B'],
#    'Trust': ['ExtendWarranty', 'HomeService'],
#    'ServiceMark': ['EncarMeetgo', 'EncarDiagnosisP1'],
#    'Condition': ['Inspection', 'Record', 'Resume'],
#    'Photo': '/carpicture07/pic3987/39878182_',
#    'Photos': [{'type': '001',
#      'location': '/carpicture07/pic3987/39878182_001.jpg',
#      'updatedDate': '2025-06-18T07:52:23Z',
#      'ordering': 1.0},
#     {'type': '003',
#      'location': '/carpicture07/pic3987/39878182_003.jpg',
#      'updatedDate': '2025-06-18T07:52:23Z',
#      'ordering': 3.0},
#     {'type': '004',
#      'location': '/carpicture07/pic3987/39878182_004.jpg',
#      'updatedDate': '2025-06-18T07:52:23Z',
#      'ordering': 4.0},
#     {'type': '007',
#      'location': '/carpicture07/pic3987/39878182_007.jpg',
#      'updatedDate': '2025-06-18T07:52:23Z',
#      'ordering': 7.0}],
#    'Manufacturer': '현대',
#    'Model': '그랜저 IG 하이브리드',
#    'Badge': '익스클루시브',
#    'BadgeDetail': '스페셜',
#    'GreenType': 'Y',
#    'EvType': '하이브리드',
#    'FuelType': '가솔린+전기',
#    'Year': 201910.0,
#    'FormYear': '2019',
#    'Mileage': 76041.0,
#    'HomeServiceVerification': 'Y',
#    'ServiceCopyCar': 'DUPLICATION',
#    'Price': 2390.0,
#    'SellType': '일반',
#    'BuyType': ['Delivery'],
#    'OfficeCityState': '인천'},
#   {'Id': '40403855',
#    'Separation': ['B'],
#    'Trust': ['ExtendWarranty', 'HomeService'],
#    'ServiceMark': ['EncarMeetgo', 'EncarDiagnosisP1'],
#    'Condition': ['Inspection', 'Record', 'Resume'],
#    'Photo': '/carpicture08/pic4038/40386422_',
#    'Photos': [{'type': '001',
#      'location': '/carpicture08/pic4038/40386422_001.jpg',
#      'updatedDate': '2025-08-28T06:54:23Z',
#      'ordering': 1.0},
#     {'type': '003',
#      'location': '/carpicture08/pic4038/40386422_003.jpg',
#      'updatedDate': '2025-08-28T06:54:23Z',
#      'ordering': 3.0},
#     {'type': '004',
#      'location': '/carpicture08/pic4038/40386422_004.jpg',
#      'updatedDate': '2025-08-28T06:54:23Z',
#      'ordering': 4.0},
#     {'type': '007',
#      'location': '/carpicture08/pic4038/40386422_007.jpg',
#      'updatedDate': '2025-08-28T06:54:23Z',
#      'ordering': 7.0}],
#    'Manufacturer': '현대',
#    'Model': '그랜저 HG',
#    'Badge': 'HG240 모던',
#    'GreenType': 'N',
#    'FuelType': '가솔린',
#    'Year': 201512.0,
#    'FormYear': '2016',
#    'Mileage': 129423.0,
#    'HomeServiceVerification': 'Y',
#    'ServiceCopyCar': 'DUPLICATION',
#    'Price': 820.0,
#    'SellType': '일반',
#    'BuyType': ['Delivery'],
#    'OfficeCityState': '인천'},
#   {'Id': '40416822',
#    'Separation': ['B'],
#    'Trust': ['ExtendWarranty', 'HomeService'],
#    'ServiceMark': ['EncarMeetgo', 'EncarDiagnosisP1'],
#    'Condition': ['Inspection', 'Record', 'Resume'],
#    'Photo': '/carpicture06/pic3996/39961154_',
#    'Photos': [{'type': '001',
#      'location': '/carpicture06/pic3996/39961154_001.jpg',
#      'updatedDate': '2025-06-30T01:41:11Z',
#      'ordering': 1.0},
#     {'type': '003',
#      'location': '/carpicture06/pic3996/39961154_003.jpg',
#      'updatedDate': '2025-06-30T01:41:11Z',
#      'ordering': 3.0},
#     {'type': '004',
#      'location': '/carpicture06/pic3996/39961154_004.jpg',
#      'updatedDate': '2025-06-30T01:41:11Z',
#      'ordering': 4.0},
#     {'type': '007',
#      'location': '/carpicture06/pic3996/39961154_007.jpg',
#      'updatedDate': '2025-06-30T01:41:11Z',
#      'ordering': 7.0}],
#    'Manufacturer': '현대',
#    'Model': '그랜저 IG',
#    'Badge': '3.0 익스클루시브',
#    'BadgeDetail': '(세부등급 없음)',
#    'GreenType': 'N',
#    'FuelType': '가솔린',
#    'Year': 201703.0,
#    'FormYear': '2017',
#    'Mileage': 142458.0,
#    'HomeServiceVerification': 'Y',
#    'ServiceCopyCar': 'DUPLICATION',
#    'Price': 1320.0,
#    'SellType': '일반',
#    'BuyType': ['Delivery'],
#    'OfficeCityState': '인천'},
#   {'Id': '40413983',
#    'Separation': ['B'],
#    'Trust': ['ExtendWarranty', 'HomeService'],
#    'ServiceMark': ['EncarMeetgo', 'EncarDiagnosisP1'],
#    'Condition': ['Inspection', 'Record', 'Resume'],
#    'Photo': '/carpicture01/pic4041/40412481_',
#    'Photos': [{'type': '001',
#      'location': '/carpicture01/pic4041/40412481_001.jpg',
#      'updatedDate': '2025-08-29T07:31:24Z',
#      'ordering': 1.0},
#     {'type': '003',
#      'location': '/carpicture01/pic4041/40412481_003.jpg',
#      'updatedDate': '2025-08-29T07:31:24Z',
#      'ordering': 3.0},
#     {'type': '004',
#      'location': '/carpicture01/pic4041/40412481_004.jpg',
#      'updatedDate': '2025-08-29T07:31:24Z',
#      'ordering': 4.0},
#     {'type': '007',
#      'location': '/carpicture01/pic4041/40412481_007.jpg',
#      'updatedDate': '2025-08-29T07:31:24Z',
#      'ordering': 7.0}],
#    'Manufacturer': '현대',
#    'Model': '더 뉴 그랜저 IG',
#    'Badge': '3.0 LPi',
#    'BadgeDetail': '익스클루시브',
#    'GreenType': 'N',
#    'FuelType': 'LPG(일반인 구입)',
#    'Year': 202009.0,
#    'FormYear': '2020',
#    'Mileage': 44580.0,
#    'HomeServiceVerification': 'Y',
#    'ServiceCopyCar': 'DUPLICATION',
#    'Price': 2699.0,
#    'SellType': '일반',
#    'BuyType': ['Delivery'],
#    'OfficeCityState': '서울'},
#   {'Id': '40297121',
#    'Separation': ['B'],
#    'Trust': ['ExtendWarranty', 'HomeService'],
#    'ServiceMark': ['EncarMeetgo', 'EncarDiagnosisP1'],
#    'Condition': ['Inspection', 'Record', 'Resume'],
#    'Photo': '/carpicture08/pic4028/40284544_',
#    'Photos': [{'type': '001',
#      'location': '/carpicture08/pic4028/40284544_001.jpg',
#      'updatedDate': '2025-08-13T05:23:12Z',
#      'ordering': 1.0},
#     {'type': '003',
#      'location': '/carpicture08/pic4028/40284544_003.jpg',
#      'updatedDate': '2025-08-13T05:23:12Z',
#      'ordering': 3.0},
#     {'type': '004',
#      'location': '/carpicture08/pic4028/40284544_004.jpg',
#      'updatedDate': '2025-08-13T05:23:12Z',
#      'ordering': 4.0},
#     {'type': '007',
#      'location': '/carpicture08/pic4028/40284544_007.jpg',
#      'updatedDate': '2025-08-13T05:23:12Z',
#      'ordering': 7.0}],
#    'Manufacturer': '현대',
#    'Model': '더 뉴 그랜저 IG',
#    'Badge': '2.5',
#    'BadgeDetail': '프리미엄',
#    'GreenType': 'N',
#    'FuelType': '가솔린',
#    'Year': 202012.0,
#    'FormYear': '2021',
#    'Mileage': 111168.0,
#    'HomeServiceVerification': 'Y',
#    'ServiceCopyCar': 'DUPLICATION',
#    'Price': 1860.0,
#    'SellType': '일반',
#    'BuyType': ['Delivery'],
#    'OfficeCityState': '부산'},
#   {'Id': '40404661',
#    'Separation': ['B'],
#    'Trust': ['ExtendWarranty', 'HomeService'],
#    'ServiceMark': ['EncarMeetgo', 'EncarDiagnosisP1'],
#    'Condition': ['Inspection', 'Record', 'Resume'],
#    'Photo': '/carpicture10/pic4040/40400328_',
#    'Photos': [{'type': '001',
#      'location': '/carpicture10/pic4040/40400328_001.jpg',
#      'updatedDate': '2025-08-28T07:36:33Z',
#      'ordering': 1.0},
#     {'type': '003',
#      'location': '/carpicture10/pic4040/40400328_003.jpg',
#      'updatedDate': '2025-08-28T07:36:33Z',
#      'ordering': 3.0},
#     {'type': '004',
#      'location': '/carpicture10/pic4040/40400328_004.jpg',
#      'updatedDate': '2025-08-28T07:36:33Z',
#      'ordering': 4.0},
#     {'type': '007',
#      'location': '/carpicture10/pic4040/40400328_007.jpg',
#      'updatedDate': '2025-08-28T07:36:33Z',
#      'ordering': 7.0}],
#    'Manufacturer': '현대',
#    'Model': '더 뉴 그랜저 IG',
#    'Badge': '2.5',
#    'BadgeDetail': '프리미엄 초이스',
#    'GreenType': 'N',
#    'FuelType': '가솔린',
#    'Year': 202006.0,
#    'FormYear': '2020',
#    'Mileage': 113927.0,
#    'HomeServiceVerification': 'Y',
#    'ServiceCopyCar': 'DUPLICATION',
#    'Price': 1820.0,
#    'SellType': '일반',
#    'BuyType': ['Delivery'],
#    'OfficeCityState': '부산'},
#   {'Id': '40393565',
#    'Separation': ['B'],
#    'Trust': ['Warranty'],
#    'ServiceMark': ['EncarDiagnosisP0'],
#    'Condition': ['Inspection', 'Record', 'Resume'],
#    'Photo': '/carpicture09/pic4039/40393565_',
#    'Photos': [{'type': '001',
#      'location': '/carpicture09/pic4039/40393565_001.jpg',
#      'updatedDate': '2025-08-27T07:59:53Z',
#      'ordering': 1.0},
#     {'type': '003',
#      'location': '/carpicture09/pic4039/40393565_003.jpg',
#      'updatedDate': '2025-08-27T07:59:53Z',
#      'ordering': 3.0},
#     {'type': '004',
#      'location': '/carpicture09/pic4039/40393565_004.jpg',
#      'updatedDate': '2025-08-27T07:59:53Z',
#      'ordering': 4.0},
#     {'type': '007',
#      'location': '/carpicture09/pic4039/40393565_007.jpg',
#      'updatedDate': '2025-08-27T07:59:53Z',
#      'ordering': 7.0}],
#    'Manufacturer': '현대',
#    'Model': '더 뉴 그랜저 IG',
#    'Badge': '2.5',
#    'BadgeDetail': '르블랑',
#    'GreenType': 'N',
#    'FuelType': '가솔린',
#    'Year': 202207.0,
#    'FormYear': '2023',
#    'Mileage': 95044.0,
#    'ServiceCopyCar': 'ORIGINAL',
#    'Price': 2200.0,
#    'SellType': '일반',
#    'BuyType': [],
#    'OfficeCityState': '대전'},
#   {'Id': '40313261',
#    'Separation': ['B'],
#    'Trust': ['Warranty', 'ExtendWarranty'],
#    'ServiceMark': ['EncarDiagnosisP0'],
#    'Condition': ['Inspection', 'Record', 'Resume'],
#    'Photo': '/carpicture01/pic4031/40313261_',
#    'Photos': [{'type': '001',
#      'location': '/carpicture01/pic4031/40313261_001.jpg',
#      'updatedDate': '2025-08-18T00:27:48Z',
#      'ordering': 1.0},
#     {'type': '003',
#      'location': '/carpicture01/pic4031/40313261_003.jpg',
#      'updatedDate': '2025-08-18T00:27:48Z',
#      'ordering': 3.0},
#     {'type': '004',
#      'location': '/carpicture01/pic4031/40313261_004.jpg',
#      'updatedDate': '2025-08-18T00:27:48Z',
#      'ordering': 4.0},
#     {'type': '007',
#      'location': '/carpicture01/pic4031/40313261_007.jpg',
#      'updatedDate': '2025-08-18T00:27:48Z',
#      'ordering': 7.0}],
#    'Manufacturer': '현대',
#    'Model': '그랜저 IG',
#    'Badge': '3.0 익스클루시브',
#    'BadgeDetail': '(세부등급 없음)',
#    'GreenType': 'N',
#    'FuelType': '가솔린',
#    'Year': 201807.0,
#    'FormYear': '2018',
#    'Mileage': 125244.0,
#    'ServiceCopyCar': 'ORIGINAL',
#    'Price': 1480.0,
#    'SellType': '일반',
#    'BuyType': [],
#    'OfficeCityState': '경기'},
#   {'Id': '40442677',
#    'Separation': ['B'],
#    'Trust': ['Warranty'],
#    'ServiceMark': ['EncarDiagnosisP0'],
#    'Condition': ['Inspection', 'Record', 'Resume'],
#    'Photo': '/carpicture04/pic4044/40442677_',
#    'Photos': [{'type': '001',
#      'location': '/carpicture04/pic4044/40442677_001.jpg',
#      'updatedDate': '2025-09-03T07:16:24Z',
#      'ordering': 1.0},
#     {'type': '003',
#      'location': '/carpicture04/pic4044/40442677_003.jpg',
#      'updatedDate': '2025-09-03T07:16:24Z',
#      'ordering': 3.0},
#     {'type': '004',
#      'location': '/carpicture04/pic4044/40442677_004.jpg',
#      'updatedDate': '2025-09-03T07:16:24Z',
#      'ordering': 4.0},
#     {'type': '007',
#      'location': '/carpicture04/pic4044/40442677_007.jpg',
#      'updatedDate': '2025-09-03T07:16:24Z',
#      'ordering': 7.0}],
#    'Manufacturer': '현대',
#    'Model': '그랜저 HG',
#    'Badge': 'HG300 익스클루시브',
#    'GreenType': 'N',
#    'FuelType': '가솔린',
#    'Year': 201404.0,
#    'FormYear': '2014',
#    'Mileage': 139202.0,
#    'ServiceCopyCar': 'ORIGINAL',
#    'Price': 730.0,
#    'SellType': '일반',
#    'BuyType': [],
#    'OfficeCityState': '경기'},
#   {'Id': '40574481',
#    'Separation': ['B'],
#    'Trust': ['HomeService'],
#    'ServiceMark': ['EncarMeetgo', 'EncarDiagnosisP0'],
#    'Condition': ['Inspection', 'Record', 'Resume'],
#    'Photo': '/carpicture06/pic4056/40561079_',
#    'Photos': [{'type': '001',
#      'location': '/carpicture06/pic4056/40561079_001.jpg',
#      'updatedDate': '2025-09-19T02:29:34Z',
#      'ordering': 1.0},
#     {'type': '003',
#      'location': '/carpicture06/pic4056/40561079_003.jpg',
#      'updatedDate': '2025-09-19T02:29:34Z',
#      'ordering': 3.0},
#     {'type': '004',
#      'location': '/carpicture06/pic4056/40561079_004.jpg',
#      'updatedDate': '2025-09-19T02:29:34Z',
#      'ordering': 4.0},
#     {'type': '007',
#      'location': '/carpicture06/pic4056/40561079_007.jpg',
#      'updatedDate': '2025-09-19T02:29:34Z',
#      'ordering': 7.0}],
#    'Manufacturer': '현대',
#    'Model': '더 뉴 그랜저 IG 하이브리드',
#    'Badge': '르블랑',
#    'GreenType': 'Y',
#    'EvType': '하이브리드',
#    'FuelType': '가솔린+전기',
#    'Year': 202108.0,
#    'FormYear': '2022',
#    'Mileage': 114873.0,
#    'ServiceCopyCar': 'DUPLICATION',
#    'Price': 2580.0,
#    'SellType': '일반',
#    'BuyType': ['Delivery'],
#    'OfficeCityState': '경기'},
#   {'Id': '40186535',
#    'Separation': ['B'],
#    'Trust': ['ExtendWarranty', 'HomeService'],
#    'ServiceMark': ['EncarMeetgo', 'EncarDiagnosisP0'],
#    'Condition': ['Inspection'],
#    'Photo': '/carpicture08/pic4018/40182453_',
#    'Photos': [{'type': '001',
#      'location': '/carpicture08/pic4018/40182453_001.jpg',
#      'updatedDate': '2025-07-29T01:23:20Z',
#      'ordering': 1.0},
#     {'type': '003',
#      'location': '/carpicture08/pic4018/40182453_003.jpg',
#      'updatedDate': '2025-07-29T01:23:20Z',
#      'ordering': 3.0},
#     {'type': '004',
#      'location': '/carpicture08/pic4018/40182453_004.jpg',
#      'updatedDate': '2025-07-29T01:23:20Z',
#      'ordering': 4.0},
#     {'type': '007',
#      'location': '/carpicture08/pic4018/40182453_007.jpg',
#      'updatedDate': '2025-07-29T01:23:20Z',
#      'ordering': 7.0}],
#    'Manufacturer': '현대',
#    'Model': '더 뉴 그랜저 IG',
#    'Badge': '2.5',
#    'BadgeDetail': '르블랑',
#    'GreenType': 'N',
#    'FuelType': '가솔린',
#    'Year': 202206.0,
#    'FormYear': '2022',
#    'Mileage': 53834.0,
#    'ServiceCopyCar': 'DUPLICATION',
#    'Price': 2790.0,
#    'SellType': '일반',
#    'BuyType': ['Delivery'],
#    'OfficeCityState': '경기'}]}

# %%
CarSeq = '40377623'

response = requests.get(f'https://api.encar.com/v1/readside/vehicle/{CarSeq}?include=CATEGORY,SPEC,OPTIONS,PHOTOS,CONDITION,CONTENTS,VIN,MANAGE', headers=headers)

response.status_code
# Out:
# 200

# %%
CarSeq = '40428124'

response = requests.get(f"https://api.encar.com/v1/readside/inspection/vehicle/{CarSeq}", headers=headers)

response.status_code
# Out:
# 200

# %%
response.json()
# Out:
# {'manage': {'dummy': False,
#   'dummyVehicleId': None,
#   'reRegistered': False,
#   'webReserved': True,
#   'registDateTime': '2025-08-26T08:27:30',
#   'firstAdvertisedDateTime': '2025-08-27T09:43:00',
#   'modifyDateTime': '2025-09-25T16:43:02',
#   'subscribeCount': 3,
#   'viewCount': 673},
#  'category': {'type': 'CAR',
#   'manufacturerCd': '001',
#   'manufacturerName': '현대',
#   'modelCd': '125',
#   'modelName': '그랜저 HG 하이브리드',
#   'gradeCd': '001',
#   'gradeName': '프리미엄',
#   'gradeEnglishName': 'Premium',
#   'yearMonth': '201412',
#   'formYear': '2015',
#   'domestic': True,
#   'importType': 'NONE_IMPORT_TYPE',
#   'originPrice': 3603,
#   'manufacturerEnglishName': 'Hyundai',
#   'modelGroupCd': '004',
#   'modelGroupName': '그랜저',
#   'modelGroupEnglishName': 'Grandeur',
#   'gradeDetailCd': None,
#   'gradeDetailName': None,
#   'gradeDetailEnglishName': None,
#   'jatoVehicleId': 726188120140101,
#   'warranty': {'userDefined': False,
#    'companyName': None,
#    'bodyMonth': 36,
#    'bodyMileage': 60000,
#    'transmissionMonth': 60,
#    'transmissionMileage': 100000}},
#  'advertisement': None,
#  'contact': None,
#  'spec': {'type': 'CAR',
#   'mileage': 144009,
#   'displacement': 2359,
#   'transmissionName': '오토',
#   'fuelCd': '006',
#   'fuelName': '가솔린+전기',
#   'colorName': '검정색',
#   'customColor': None,
#   'seatCount': 5,
#   'bodyName': '대형차'},
#  'photos': [{'code': '010',
#    'path': '/carpicture07/pic4037/40377623_010.jpg',
#    'type': 'INNER',
#    'updateDateTime': '2025-08-27T11:57:03',
#    'desc': None},
#   {'code': '007',
#    'path': '/carpicture07/pic4037/40377623_007.jpg',
#    'type': 'INNER',
#    'updateDateTime': '2025-08-27T11:57:03',
#    'desc': None},
#   {'code': '011',
#    'path': '/carpicture07/pic4037/40377623_001.jpg',
#    'type': 'THUMBNAIL',
#    'updateDateTime': '2025-08-27T11:57:03',
#    'desc': None},
#   {'code': '012',
#    'path': '/carpicture07/pic4037/40377623_001.jpg',
#    'type': 'THUMBNAIL',
#    'updateDateTime': '2025-08-27T11:57:03',
#    'desc': None},
#   {'code': '018',
#    'path': '/carpicture07/pic4037/40377623_018.jpg',
#    'type': 'OPTION',
#    'updateDateTime': '2025-08-27T11:57:03',
#    'desc': None},
#   {'code': '003',
#    'path': '/carpicture07/pic4037/40377623_003.jpg',
#    'type': 'OUTER',
#    'updateDateTime': '2025-08-27T11:57:03',
#    'desc': '전국최저가! 하부누유X(리프트확인가능).모든옵션 정상작동.'},
#   {'code': '016',
#    'path': '/carpicture07/pic4037/40377623_016.jpg',
#    'type': 'OPTION',
#    'updateDateTime': '2025-08-27T11:57:03',
#    'desc': None},
#   {'code': '009',
#    'path': '/carpicture07/pic4037/40377623_009.jpg',
#    'type': 'INNER',
#    'updateDateTime': '2025-08-27T11:57:03',
#    'desc': None},
#   {'code': '020',
#    'path': '/carpicture07/pic4037/40377623_020.jpg',
#    'type': 'OPTION',
#    'updateDateTime': '2025-08-27T11:57:03',
#    'desc': None},
#   {'code': '008',
#    'path': '/carpicture07/pic4037/40377623_008.jpg',
#    'type': 'INNER',
#    'updateDateTime': '2025-08-27T11:57:03',
#    'desc': None},
#   {'code': '021',
#    'path': '/carpicture07/pic4037/40377623_021.jpg',
#    'type': 'OPTION',
#    'updateDateTime': '2025-08-27T11:57:03',
#    'desc': None},
#   {'code': '023',
#    'path': '/carpicture07/pic4037/40377623_023.jpg',
#    'type': 'OPTION',
#    'updateDateTime': '2025-08-27T11:57:03',
#    'desc': None},
#   {'code': '006',
#    'path': '/carpicture07/pic4037/40377623_006.jpg',
#    'type': 'INNER',
#    'updateDateTime': '2025-08-27T11:57:03',
#    'desc': None},
#   {'code': '005',
#    'path': '/carpicture07/pic4037/40377623_005.jpg',
#    'type': 'OUTER',
#    'updateDateTime': '2025-08-27T11:57:03',
#    'desc': '전국최저가! 하부누유X(리프트확인가능).모든옵션 정상작동.'},
#   {'code': '019',
#    'path': '/carpicture07/pic4037/40377623_019.jpg',
#    'type': 'OPTION',
#    'updateDateTime': '2025-08-27T11:57:03',
#    'desc': None},
#   {'code': '026',
#    'path': '/carpicture07/pic4037/40377623_001.jpg',
#    'type': 'THUMBNAIL',
#    'updateDateTime': '2025-08-27T11:57:03',
#    'desc': None},
#   {'code': '025',
#    'path': '/carpicture07/pic4037/40377623_001.jpg',
#    'type': 'THUMBNAIL',
#    'updateDateTime': '2025-08-27T11:57:03',
#    'desc': None},
#   {'code': '014',
#    'path': '/carpicture07/pic4037/40377623_007.jpg',
#    'type': 'THUMBNAIL',
#    'updateDateTime': '2025-08-27T11:57:03',
#    'desc': None},
#   {'code': '024',
#    'path': '/carpicture07/pic4037/40377623_024.jpg',
#    'type': 'OPTION',
#    'updateDateTime': '2025-08-27T11:57:03',
#    'desc': None},
#   {'code': '002',
#    'path': '/carpicture07/pic4037/40377623_002.jpg',
#    'type': 'OUTER',
#    'updateDateTime': '2025-08-27T11:57:03',
#    'desc': '전국최저가! 하부누유X(리프트확인가능).모든옵션 정상작동.'},
#   {'code': '015',
#    'path': '/carpicture07/pic4037/40377623_015.jpg',
#    'type': 'OPTION',
#    'updateDateTime': '2025-08-27T11:57:03',
#    'desc': None},
#   {'code': '022',
#    'path': '/carpicture07/pic4037/40377623_022.jpg',
#    'type': 'OPTION',
#    'updateDateTime': '2025-08-27T11:57:03',
#    'desc': None},
#   {'code': '013',
#    'path': '/carpicture07/pic4037/40377623_001.jpg',
#    'type': 'THUMBNAIL',
#    'updateDateTime': '2025-08-27T11:57:03',
#    'desc': None},
#   {'code': '017',
#    'path': '/carpicture07/pic4037/40377623_017.jpg',
#    'type': 'OPTION',
#    'updateDateTime': '2025-08-27T11:57:03',
#    'desc': None},
#   {'code': '001',
#    'path': '/carpicture07/pic4037/40377623_001.jpg',
#    'type': 'OUTER',
#    'updateDateTime': '2025-08-27T11:57:03',
#    'desc': '전국최저가! 하부누유X(리프트확인가능).모든옵션 정상작동.'},
#   {'code': '004',
#    'path': '/carpicture07/pic4037/40377623_004.jpg',
#    'type': 'OUTER',
#    'updateDateTime': '2025-08-27T11:57:03',
#    'desc': '전국최저가! 하부누유X(리프트확인가능).모든옵션 정상작동.'}],
#  'options': {'type': 'CAR',
#   'standard': ['001',
#    '003',
#    '004',
#    '005',
#    '006',
#    '007',
#    '008',
#    '014',
#    '015',
#    '017',
#    '019',
#    '020',
#    '021',
#    '022',
#    '023',
#    '024',
#    '026',
#    '027',
#    '030',
#    '031',
#    '032',
#    '033',
#    '035',
#    '055',
#    '056',
#    '057',
#    '058',
#    '063',
#    '068',
#    '071',
#    '072',
#    '074',
#    '082',
#    '085',
#    '094',
#    '096',
#    '097'],
#   'etc': [],
#   'choice': [],
#   'tuning': []},
#  'condition': {'accident': {'recordView': False, 'resumeView': True},
#   'inspection': {'formats': []},
#   'seizing': {'seizingCount': 0, 'pledgeCount': 0}},
#  'partnership': None,
#  'contents': {'text': '『안녕하세요』중고차 판매 전문딜러 프로모터스 “이병희”입니다\n\n 엔카광고 판매대수 연간 “180대이상” 직접 매입&직접 판매합니다.\n\n▣▣▣▣▣▣▣▣▣▣▣▣▣▣▣▣▣▣▣▣▣▣▣▣▣▣\n\n▣ 판매자의 한마디\n\n\n                         ★침수차량.전손차량.키로수이상(원부.갑부등 전부 확인합니다) 있는 차량들은  일체 취급하지 않습니다!! (계약서명시)★\n\n\n★ 엔진.밋션.및 하부상태 확실하게 체크하였습니다 \n\n★ 모든옵션 정상유뮤  체크하였습니다\n\n★ 실내및 외관상태 너무 깨끗하게 관리 하셨습니다 \n\n★ 하부.부식.누유 없습니다(오시면 리프트 확인가능)\n\n★ 주유만하시고 운행하셔도 될정도로  차량 컨디션 아주 좋습니다 \n\n ★삼성화재(손해보험) ◀ 가입완료한 차량이며 확실한 \n\n    성능업체 1, 2차 성능완료 하였습니다 ★\n\n\n\n\n▶  차량 + 등록비 + 보험료까지 전액할부 및 추가할부가능.\n\n ▶  연  식 :  2014년 12월\n\n ▶  차량명:  그랜져HG 하이브리드 \n\n ▶  사고유무 : 본넷.트렁크쪽교환\n\n ▶  주행거리 144.008km\n\n ━━☆━━━━━━☆━━━━━━☆━━━━━━☆━━━━━━☆\n\n   출발 전 사전 예약을 주시면, 시승과 점검이 가능하도록 차량을 \n\n   준비합니다.  3가지 생각만 버리고 오시면됩니다 \n\n  (허위매물, 침수유무 조작,키로수조작)\n\n  제가 판매하는 차량에는 해당사항이 없음을 당당하게 밝힙니다.\n\n▧▧▧▧▧▧▧▧▧▧▧▧▧▧▧▧▧▧▧▧▧\n\n  (신주소) 대구 북구 노원로 115  오토월드\n\n    4층 403호 프로모터스 오시면됩니다\n\n ▧▧▧▧▧▧▧▧▧▧▧▧▧▧▧▧▧▧▧▧▧\n\n 버스 이용시 한국로봇산업진흥원앞 정류소 하차후\n\n 오토월드입구 오셔서 엘리베이터를 이용 4층 403호\n\n 프로모터스 사무실로 오시면됩니다.\n\n 북구1, 서구1-1, 칠곡2 , 순환3-1(한국로봇산업진흥원앞)',
#   'meetGoText': None},
#  'view': None,
#  'vehicleId': 40377623,
#  'vehicleType': 'CAR',
#  'vin': 'KMHFG413BFA012859',
#  'vehicleNo': '110구7086'}
